# %%
import os
import cv2
import numpy as np
from rasterio.mask import mask
from shapely.geometry import mapping

# %%
def openRawImgPath(rawImgPath):
    ''' open rawImgPath to get raw img path in dict
    # return{
            'file1name':
                '1':
                    [filename, (x,y),(x,y),(x,y),(x,y)], ... *10
                    ...
                '115':
                    [filename, (x,y),(x,y),(x,y),(x,y)], ... *10
            'file2name':
            ...
            }
    '''
    rawImgPathDict = {}

    #loop in each file
    for file in os.listdir(rawImgPath):

        #open file
        rawImgFiles = open(rawImgPath + '/' + file,'r').read()
        #split each line
        allLines = rawImgFiles.split('\n')
        key = []
        data = []
        #loop each line in enumerate
        for countLine, line in enumerate(allLines):

            #check if that line is key(1-115)
            try:
                int(line)
                # add to key
                key.append(line)

            #if not key >> path data
            except:

                #'filename:[x,y],[x,y],[x,y],[x,y]' >> 'filename','[x,y],[x,y],[x,y],[x,y]'
                splittedLine = line.split(':')
                
                #loop each coor >> [x y]
                coorlist = [splittedLine[0]]
                for coor in splittedLine[1].split(','):
                    #'[x y]' >> 'x y'
                    coor = coor[1:-1]
                    #'x y' >> '(x,y)'
                    coors = tuple(coor.split())
                    # append each tuple of x,y to coor list
                    coorlist.append(coors)

                #add precessed path to data
                data.append(coorlist)

        # assign key and data to dict:   key(x): data(x:x+10)
        labelDict = {}
        for count in range(len(key)):
            labelDict[key[count]] = data[count*10:count*10+10]
            
        # assign labelDict (key = 1-115) to main dict(file)
        rawImgPathDict[file[:-4]] = labelDict

    return rawImgPathDict

def getAllfilePath(filePath):
    '''
    get all of the file path in the path 
    '''
    fileList = []
    # loop into each file
    for fileName in os.listdir(filePath):
        #add original path
        fileNamePath = filePath + '/' + fileName
        #add to list
        fileList.append(fileNamePath)
    return(fileList)

def ClipSaveRawdata(rawPath, coor, outPath):
    '''
    clip and save JPG data to output path using 4 coordinates
    '''
    if(not(os.path.exists(outPath))):
        # Load image
        image = cv2.imread(rawPath)

        # Convert coordinates to integers
        coordinates = np.array(coor, dtype=np.float32)

        # Get bounding box (min/max coordinates)
        x_min, y_min = np.min(coordinates, axis=0)
        x_max, y_max = np.max(coordinates, axis=0)

        # Convert to integer values
        x_min, y_min, x_max, y_max = map(int, [x_min, y_min, x_max, y_max])

        # Crop the image
        cropped_image = image[y_min:y_max, x_min:x_max]

        # Save the cropped image
        cv2.imwrite(outPath, cropped_image)

        # print(f"Cropped image saved to {outPath}")


def loopClipSaveRawdata(rawImgPathDict, rawImgFilePathList, outputFilePathList, clipNum):
    '''
    clip and save jpg data to outpust path
    '''
    # loop into mainFileName(key (file name)) and dataLabelDict(dict value [1-115])
    mainFlieCount = 0 
    for mainFileName, dataLabelDict in rawImgPathDict.items():

        # get raw imgfile path 
        rawImgFilePath = rawImgFilePathList[mainFlieCount]
        # get output file path
        outputFilePath = outputFilePathList[mainFlieCount]

        labelCount = 1
        # loop into dataLabel(key 1-115) and fileCoorList(list value*10 [filename, coor1 - 4])
        for dataLabel, fileCoorList in dataLabelDict.items():

            # assign output file path
            LabelOutputFilePath = outputFilePath + "/RGB_" + mainFileName + "_" + str(labelCount)

            #loop only first (clipNum) number of fileCoorList
            for clipDataCount in range(clipNum):

                eachLabelOutputFilePath = LabelOutputFilePath + "/RGB_" + mainFileName + "_" + str(labelCount) + "_raw" + str(clipDataCount+1) + '.jpg'

                # separate data >> filename, [coor]
                targetData = fileCoorList[clipDataCount]
                targetFileName = targetData[0]
                targetCoor = targetData[1:]

                # assign target file path
                targetFilePath = rawImgFilePath + '/' + targetFileName + '.jpg'

                # check if file already exist
                if(not(os.path.exists(eachLabelOutputFilePath))):
                    # call ClipSaveRawdata to clip and save
                    # print("clipping image to ", eachLabelOutputFilePath)
                    ClipSaveRawdata(targetFilePath, targetCoor, eachLabelOutputFilePath)
                else:
                    print("image already exist")
            
            print(f"{mainFlieCount+1} / 16 >>> {labelCount} / 60")

            labelCount += 1
                
        mainFlieCount += 1

# %%
if __name__ == '__main__':
    rawImgFilePathList = sorted(getAllfilePath(filePath = "/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix"))
    rawImgPathData = "/Volumes/PortableSSD/MasterProj/rawImage/2025/rawImgPathData"
    rawImgPathDict = openRawImgPath(rawImgPathData)


    outputPath = "/Volumes/PortableSSD/dataForProcess/2025MainData/RGB"
    outputPathList = sorted(getAllfilePath(outputPath))

    loopClipSaveRawdata(rawImgPathDict, rawImgFilePathList, outputPathList, 10)
# Out:
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 1 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 2 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 3 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 4 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 5 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 6 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 7 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 8 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 9 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 10 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 11 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 12 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 13 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 14 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 15 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 16 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 17 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 18 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 19 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 20 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 21 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 22 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 23 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 24 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 25 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 26 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 27 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 28 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 29 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 30 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 31 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 32 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 33 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 34 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 35 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 36 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 37 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 38 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 39 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 40 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 41 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 42 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 43 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 44 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 45 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 46 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 47 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 48 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 49 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 50 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 51 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 52 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 53 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 54 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 55 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 56 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 57 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 58 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 59 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 1 / 16 >>> 60 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 1 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 2 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 3 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 4 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 5 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 6 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 7 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 8 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 9 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 10 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 11 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 12 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 13 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 14 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 15 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 16 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 17 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 18 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 19 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 20 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 21 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 22 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 23 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 24 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 25 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 26 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 27 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 28 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 29 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 30 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 31 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 32 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 33 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 34 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 35 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 36 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 37 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 38 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 39 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 40 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 41 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 42 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 43 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 44 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 45 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 46 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 47 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 48 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 49 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 50 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 51 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 52 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 53 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 54 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 55 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 56 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 57 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 58 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 59 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 2 / 16 >>> 60 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 1 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 2 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 3 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 4 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 5 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 6 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 7 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 8 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 9 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 10 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 11 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 12 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 13 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 14 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 15 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 16 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 17 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 18 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 19 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 20 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 21 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 22 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 23 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 24 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 25 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 26 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 27 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 28 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 29 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 30 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 31 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 32 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 33 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 34 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 35 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 36 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 37 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 38 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 39 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 40 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 41 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 42 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 43 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 44 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 45 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 46 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 47 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 48 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 49 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 50 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 51 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 52 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 53 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 54 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 55 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 56 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 57 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 58 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 59 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 3 / 16 >>> 60 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 1 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 2 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 3 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 4 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 5 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 6 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 7 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 8 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 9 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 10 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 11 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 12 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 13 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 14 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 15 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 16 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 17 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 18 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 19 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 20 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 21 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 22 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 23 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 24 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 25 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 26 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 27 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 28 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 29 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 30 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 31 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 32 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 33 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 34 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 35 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 36 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 37 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 38 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 4 / 16 >>> 39 / 60
# image already exist
# image already exist
# image already exist
# ...
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 48 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 49 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 50 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 51 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 52 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 53 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 54 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 55 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 56 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 57 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 58 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 59 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 15 / 16 >>> 60 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 1 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 2 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 3 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 4 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 5 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 6 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 7 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 8 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 9 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 10 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 11 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 12 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 13 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 14 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 15 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 16 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 17 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 18 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 19 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 20 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 21 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 22 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 23 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 24 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 25 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 26 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 27 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 28 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 29 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 30 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 31 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 32 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 33 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 34 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 35 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 36 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 37 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 38 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 39 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 40 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 41 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 42 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 43 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 44 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 45 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 46 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 47 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 48 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 49 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 50 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 51 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 52 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 53 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 54 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 55 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 56 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 57 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 58 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 59 / 60
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# image already exist
# 16 / 16 >>> 60 / 60

# %%
rawImgFilePathList, sorted(outputPathList)
# Out:
# (['/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202503010913_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202503111011_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202503210851_001_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202503260955_001_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504040926_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504080849_001_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504170935_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504220916_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504250923_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202504301004_003_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202505070918_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202505161016_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202505201058_001_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202505291010_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202506021002_002_2025TomiokaKomugi',
#   '/Volumes/HD-PCFSU3-A/2025/RawData/RAWForPix/DJI_202506130855_001_2025TomiokaKomugi'],
#  ['/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202503010913',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202503111011',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202503210851',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202503260955',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504040926',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504080849',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504170935',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504220916',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504250923',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202504301004',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202505070918',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202505161016',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202505201058',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202505291010',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202506021002',
#   '/Volumes/PortableSSD/dataForProcess/2025MainData/RGB/RGB_202506130855'])
