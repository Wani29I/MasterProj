# %%
import os
import cv2
import random
import rasterio
import numpy as np
from PIL import Image, ImageEnhance
import geopandas as gpd
from datetime import datetime

# %%
def getEnhancedDataPath(dataPath):
    '''  
    get all enhanced data path as list
    '''
    EnhancedDataPathList = []
    #loop into day folder
    for mainFolder in os.listdir(dataPath):
        mainFolderPath = dataPath + '/' + mainFolder

        #loop into label folder
        for labelFolder in os.listdir(mainFolderPath):
            labelFolderPath = mainFolderPath + '/' + labelFolder

            # loop into every file
            for dataFile in os.listdir(labelFolderPath):

                # check enhanced folder
                if(dataFile == 'Enhanced'):
                    enhancedFolderPath = labelFolderPath + "/" + dataFile

                    # loop into enhanced folder
                    for enhancedFile in os.listdir(enhancedFolderPath):
                        enhancedFilePath = enhancedFolderPath + "/" + enhancedFile
                        EnhancedDataPathList.append(enhancedFilePath)
                
        # print(mainFolder)
    return EnhancedDataPathList

def readJPGImg(path):
    '''
    read jpg and return image
    '''
    try:
        # check if image exist, then read and return image
        image = cv2.imread(path)
        return image
    except:
        print("could not read image")

def saveJPGImg(path, image):
    '''
    save jpg image
    '''
    # check if image already exist, if not, save image
    if(not(os.path.exists(path))):
        cv2.imwrite(path, image)
        print(f"image saved: {path}")
    else:
        # image already exist
        print(f"image already exist: {path}")

def rotate_image(image, angle=180):
    """
    Rotate the image by the specified angle.

    Parameters:
    - image: Input image (NumPy array)
    - angle: Rotation angle (default 180°)

    Returns:
    - Rotated image
    """
    height, width = image.shape[:2]
    center = (width // 2, height // 2)  # Find the center of the image

    # Compute the rotation matrix
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

    # Perform the rotation
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height), borderMode=cv2.BORDER_REFLECT)

    return rotated_image

def flip_horizontal(image):
    """
    Applies horizontal flip to the given image.
    
    Parameters:
    - image: Input image (NumPy array)

    Returns:
    - Flipped image
    """
    return cv2.flip(image, 1)  # Flip along vertical axis (left ↔ right)

def apply_zoom(image, zoom_factor=1.2):
    """
    Applies zoom to the given image.

    Parameters:
    - image: Input image (NumPy array)
    - zoom_factor: Scale factor (>1 for zoom-in, <1 for zoom-out)

    Returns:
    - Zoomed image (same size as input)
    """
    height, width = image.shape[:2]

    # Compute new zoomed dimensions
    new_width = int(width / zoom_factor)
    new_height = int(height / zoom_factor)

    # Compute cropping coordinates
    x1 = (width - new_width) // 2
    y1 = (height - new_height) // 2
    x2 = x1 + new_width
    y2 = y1 + new_height

    # Crop and resize to original size
    cropped = image[y1:y2, x1:x2]
    zoomed_image = cv2.resize(cropped, (width, height), interpolation=cv2.INTER_LINEAR)

    return zoomed_image

def apply_gamma_correction(image, gamma):
    """
    Applies gamma correction to adjust image brightness.

    Parameters:
    - image: Input image (NumPy array)
    - gamma: Gamma value (>1 for brighter, <1 for darker)

    Returns:
    - Adjusted image
    """
    inv_gamma = 1.0 / gamma  # Inverse gamma for LUT mapping
    table = np.array([(i / 255.0) ** inv_gamma * 255 for i in np.arange(0, 256)]).astype(np.uint8)

    return cv2.LUT(image, table)  # Apply the gamma correction

def apply_color_jitter(image, brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1):
    """
    Applies Color Jitter (random changes in brightness, contrast, saturation, and hue).

    Parameters:
    - image: Input image (NumPy array, BGR format).
    - brightness: Max brightness change factor (e.g., 0.2 = ±20% change).
    - contrast: Max contrast change factor (e.g., 0.2 = ±20% change).
    - saturation: Max saturation change factor (e.g., 0.2 = ±20% change).
    - hue: Max hue shift factor (e.g., 0.1 = ±10% change).

    Returns:
    - Jittered image
    """
    # Convert BGR to HSV for color adjustments
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV).astype(np.float32)

    # Adjust brightness (Value channel)
    brightness_factor = np.random.uniform(1 - brightness, 1 + brightness)
    hsv[:, :, 2] = np.clip(hsv[:, :, 2] * brightness_factor, 0, 255)

    # Adjust saturation (Saturation channel)
    saturation_factor = np.random.uniform(1 - saturation, 1 + saturation)
    hsv[:, :, 1] = np.clip(hsv[:, :, 1] * saturation_factor, 0, 255)

    # Convert back to BGR
    jittered_image = cv2.cvtColor(hsv.astype(np.uint8), cv2.COLOR_HSV2BGR)

    # Adjust contrast
    contrast_factor = np.random.uniform(1 - contrast, 1 + contrast)
    jittered_image = np.clip((jittered_image - 127.5) * contrast_factor + 127.5, 0, 255).astype(np.uint8)

    return jittered_image

def apply_gaussian_noise(image, mean=0, std=0.6):
    """
    Applies Gaussian noise to an image.

    Parameters:
    - image: Input image (NumPy array).
    - mean: Mean of Gaussian noise (default = 0).
    - std: Standard deviation of Gaussian noise (default = 15).

    Returns:
    - Noisy image
    """
    noise = np.random.normal(mean, std, image.shape).astype(np.uint8)
    noisy_image = cv2.add(image, noise)  # Add noise to image
    return np.clip(noisy_image, 0, 255).astype(np.uint8)  # Keep values in valid range

def loopAugmentImage(targetPathList):
    ''' 
    call all the augmentation method for enhanced image and svae to "Augmented" folder
    '''
    count = 0

    # Get current time
    start_time = datetime.now()

    # loop into each target file path
    for targetPath in targetPathList:
        # create output path in Enhanced folder
        splittedPath = targetPath.split('/')
        prevFolderPath = splittedPath[:-2]
        filename = splittedPath[-1][:-4]
        # .../RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced
        outFilePath = '/'.join(prevFolderPath) + "/" + "Augmented" + "/" + filename

        # read image
        targetImgOriginal = readJPGImg(targetPath)

        # 1 save original image as one of the data
        originalImageOutPath = outFilePath + "_original.jpg"
        saveJPGImg(originalImageOutPath, targetImgOriginal)
        
        # 2 rotate image for 180 degree and save in Augmented data
        rotatedImg = rotate_image(targetImgOriginal)
        rotatedImgOutPath = outFilePath + "_rotated.jpg"
        saveJPGImg(rotatedImgOutPath, rotatedImg)

        # 3 flip image horizontally and save image to Augmented data
        flippedImg = flip_horizontal(targetImgOriginal)
        flippedImgOutPath = outFilePath + "_flipped.jpg"
        saveJPGImg(flippedImgOutPath, flippedImg)

        # 4 zoom image for 20% and save to Augmented data
        zoomedImg = apply_zoom(targetImgOriginal)
        zoomedImgOutPath = outFilePath + "_zoomed.jpg"
        saveJPGImg(zoomedImgOutPath, zoomedImg)

        # 5 apply gamma correction 1.2 (bright) to original image and save to Augmented data
        brightenOriginal = apply_gamma_correction(targetImgOriginal, gamma=1.2)
        brightenOriginalOutPath = outFilePath + "_brightenOriginal.jpg"
        saveJPGImg(brightenOriginalOutPath, brightenOriginal)

        # 6 apply gamma correction 1.2 (bright) to flipped image and save to Augmented data
        brightenFlipped = apply_gamma_correction(flippedImg, gamma=1.2)
        brightenFlippedOutPath = outFilePath + "_brightenFlipped.jpg"
        saveJPGImg(brightenFlippedOutPath, brightenFlipped)

        # 7 apply gamma correction 0.8 (dark) to original image and save to Augmented data
        darkenOriginal = apply_gamma_correction(targetImgOriginal, gamma=0.8)
        darkenOriginalOutPath = outFilePath + "_darkenOriginal.jpg"
        saveJPGImg(darkenOriginalOutPath, darkenOriginal)

        # 8 apply gamma correction 0.8 (dark) to flipped image and save to Augmented data
        darkenFlipped = apply_gamma_correction(flippedImg, gamma=0.8)
        darkenFlippedOutPath = outFilePath + "_darkenFlipped.jpg"
        saveJPGImg(darkenFlippedOutPath, darkenFlipped)

        # 9 apply random changes in brightness, contrast, saturation, and hue and save to Augmented data
        jitteredImg = apply_color_jitter(targetImgOriginal)
        jitteredImgOutPath = outFilePath + "_jittered.jpg"
        saveJPGImg(jitteredImgOutPath, jitteredImg)

        # 10 apply gaussian noise and save to Augmented image
        noiseImg = apply_gaussian_noise(targetImgOriginal)
        noiseImgOutPath = outFilePath + "_noisy.jpg"
        saveJPGImg(noiseImgOutPath, noiseImg)


        count += 1
        current_time = datetime.now()
        time_elapsed = current_time - start_time
        time_left = (len(targetPathList)/count)*time_elapsed
        print(f"{count} / {len(targetPathList)} >> {count*100/len(targetPathList):.3f}% >> estimated time until finish: {time_left}")

# %%
RGBPath = "D:/ice-wheat/data/dataForProcess/mainData/RGB"
enhancedDataPathList = getEnhancedDataPath(RGBPath)
loopAugmentImage(enhancedDataPathList)

# enhancedImg = readJPGImg("C:/Users/pacha/Desktop/masterProj/MasterProj/augmentation/test3.jpg")

# rotateImg = rotate_image(enhancedImg)
# saveJPGImg("./rotate3.jpg",rotateImg)

# flipImg = flip_horizontal(enhancedImg)
# saveJPGImg("./flip3.jpg",flipImg)

# zoomImg = apply_zoom(enhancedImg)
# saveJPGImg("./zoom3.jpg",zoomImg)

# gammaImgOriBright = apply_gamma_correction(enhancedImg, gamma=1.2)
# saveJPGImg("./gamma3.jpg",gammaImgOriBright)

# gammaImgflipBright = apply_gamma_correction(flipImg, gamma=1.2)
# saveJPGImg("./gamma3.jpg",gammaImgflipBright)

# gammaImgOriDark = apply_gamma_correction(enhancedImg, gamma=0.8)
# saveJPGImg("./gammaD3.jpg",gammaImgOriDark)

# gammaImgflipDark = apply_gamma_correction(flipImg, gamma=0.8)
# saveJPGImg("./gammaD3.jpg",gammaImgflipDark)

# jitterImg = apply_color_jitter(enhancedImg)
# saveJPGImg("./jitter3.jpg", jitterImg)

# noiseImg = apply_gaussian_noise(enhancedImg,0,0.6)
# saveJPGImg("./noise3.jpg", noiseImg)
# Out:
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_original_enhanced_noisy.jpg
# 1 / 38065 >> 0.003% >> estimated time until finish: 0:13:01.855100
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw10_enhanced_noisy.jpg
# 2 / 38065 >> 0.005% >> estimated time until finish: 0:14:16.024752
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw1_enhanced_noisy.jpg
# 3 / 38065 >> 0.008% >> estimated time until finish: 0:15:01.341135
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw2_enhanced_noisy.jpg
# 4 / 38065 >> 0.011% >> estimated time until finish: 0:15:52.871629
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw3_enhanced_noisy.jpg
# 5 / 38065 >> 0.013% >> estimated time until finish: 0:15:54.792008
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw4_enhanced_noisy.jpg
# 6 / 38065 >> 0.016% >> estimated time until finish: 0:16:17.991357
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw5_enhanced_noisy.jpg
# 7 / 38065 >> 0.018% >> estimated time until finish: 0:16:13.990906
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw6_enhanced_noisy.jpg
# 8 / 38065 >> 0.021% >> estimated time until finish: 0:16:21.396588
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw7_enhanced_noisy.jpg
# 9 / 38065 >> 0.024% >> estimated time until finish: 0:16:19.518186
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw8_enhanced_noisy.jpg
# 10 / 38065 >> 0.026% >> estimated time until finish: 0:16:20.938856
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_1/Augmented/RGB_202401181250_1_raw9_enhanced_noisy.jpg
# 11 / 38065 >> 0.029% >> estimated time until finish: 0:16:19.017958
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_original_enhanced_noisy.jpg
# 12 / 38065 >> 0.032% >> estimated time until finish: 0:16:31.586906
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw10_enhanced_noisy.jpg
# 13 / 38065 >> 0.034% >> estimated time until finish: 0:16:30.178989
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw1_enhanced_noisy.jpg
# 14 / 38065 >> 0.037% >> estimated time until finish: 0:16:34.469876
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw2_enhanced_noisy.jpg
# 15 / 38065 >> 0.039% >> estimated time until finish: 0:16:32.958515
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw3_enhanced_noisy.jpg
# 16 / 38065 >> 0.042% >> estimated time until finish: 0:16:31.243528
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw4_enhanced_noisy.jpg
# 17 / 38065 >> 0.045% >> estimated time until finish: 0:16:35.084034
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw5_enhanced_noisy.jpg
# 18 / 38065 >> 0.047% >> estimated time until finish: 0:16:39.324674
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw6_enhanced_noisy.jpg
# 19 / 38065 >> 0.050% >> estimated time until finish: 0:16:38.581183
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw7_enhanced_noisy.jpg
# 20 / 38065 >> 0.053% >> estimated time until finish: 0:16:42.264773
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw8_enhanced_noisy.jpg
# 21 / 38065 >> 0.055% >> estimated time until finish: 0:16:39.570586
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_10/Augmented/RGB_202401181250_10_raw9_enhanced_noisy.jpg
# 22 / 38065 >> 0.058% >> estimated time until finish: 0:16:39.183757
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_original_enhanced_noisy.jpg
# 23 / 38065 >> 0.060% >> estimated time until finish: 0:16:31.297005
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw10_enhanced_noisy.jpg
# 24 / 38065 >> 0.063% >> estimated time until finish: 0:16:24.237189
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw1_enhanced_noisy.jpg
# 25 / 38065 >> 0.066% >> estimated time until finish: 0:16:24.316745
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw2_enhanced_noisy.jpg
# 26 / 38065 >> 0.068% >> estimated time until finish: 0:16:27.489550
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw3_enhanced_noisy.jpg
# 27 / 38065 >> 0.071% >> estimated time until finish: 0:16:24.703485
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_rotated.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_flipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_zoomed.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_brightenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_brightenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_darkenOriginal.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_darkenFlipped.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_jittered.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw4_enhanced_noisy.jpg
# 28 / 38065 >> 0.074% >> estimated time until finish: 0:16:20.854842
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw5_enhanced_original.jpg
# image already exist: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_100/Augmented/RGB_202401181250_100_raw5_enhanced_rotated.jpg
# ...
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw5_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw5_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw5_enhanced_noisy.jpg
# 425 / 38065 >> 1.117% >> estimated time until finish: 0:54:45.665382
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw6_enhanced_noisy.jpg
# 426 / 38065 >> 1.119% >> estimated time until finish: 0:54:47.916737
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw7_enhanced_noisy.jpg
# 427 / 38065 >> 1.122% >> estimated time until finish: 0:54:50.605055
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw8_enhanced_noisy.jpg
# 428 / 38065 >> 1.124% >> estimated time until finish: 0:54:54.161998
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_3/Augmented/RGB_202401181250_3_raw9_enhanced_noisy.jpg
# 429 / 38065 >> 1.127% >> estimated time until finish: 0:54:55.545164
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_original_enhanced_noisy.jpg
# 430 / 38065 >> 1.130% >> estimated time until finish: 0:54:57.269705
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw10_enhanced_noisy.jpg
# 431 / 38065 >> 1.132% >> estimated time until finish: 0:55:00.600518
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw1_enhanced_noisy.jpg
# 432 / 38065 >> 1.135% >> estimated time until finish: 0:55:03.621875
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_darkenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_jittered.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw2_enhanced_noisy.jpg
# 433 / 38065 >> 1.138% >> estimated time until finish: 0:55:07.329040
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_original.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_rotated.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_flipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_zoomed.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_brightenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_brightenFlipped.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_darkenOriginal.jpg
# image saved: D:/ice-wheat/data/dataForProcess/mainData/RGB/RGB_202401181250/RGB_202401181250_30/Augmented/RGB_202401181250_30_raw3_enhanced_darkenFlipped.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[146], line 3
#       1 RGBPath = "D:/ice-wheat/data/dataForProcess/mainData/RGB"
#       2 enhancedDataPathList = getEnhancedDataPath(RGBPath)
# ----> 3 loopAugmentImage(enhancedDataPathList)
#       5 # enhancedImg = readJPGImg("C:/Users/pacha/Desktop/masterProj/MasterProj/augmentation/test3.jpg")
#       6
#       7 # rotateImg = rotate_image(enhancedImg)
#    (...)
#      31 # noiseImg = apply_gaussian_noise(enhancedImg,0,0.6)
#      32 # saveJPGImg("./noise3.jpg", noiseImg)
#
# Cell In[144], line 244, in loopAugmentImage(targetPathList)
#     242 jitteredImg = apply_color_jitter(targetImgOriginal)
#     243 jitteredImgOutPath = outFilePath + "_jittered.jpg"
# --> 244 saveJPGImg(jitteredImgOutPath, jitteredImg)
#     246 # 10 apply gaussian noise and save to Augmented image
#     247 noiseImg = apply_gaussian_noise(targetImgOriginal)
#
# Cell In[144], line 46, in saveJPGImg(path, image)
#      44 # check if image already exist, if not, save image
#      45 if(not(os.path.exists(path))):
# ---> 46     cv2.imwrite(path, image)
#      47     print(f"image saved: {path}")
#      48 else:
#      49     # image already exist
#
# KeyboardInterrupt:
