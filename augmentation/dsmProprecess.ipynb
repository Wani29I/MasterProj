# %%
import os
import cv2
import random
import rasterio
import numpy as np
from PIL import Image, ImageEnhance
import geopandas as gpd
from rasterio.mask import mask
from rasterio.plot import show
import matplotlib.pyplot as plt
from shapely.geometry import box
from rasterio.windows import Window

# %%
def save_raster(output_raster, data, profile):
    """
    Save raster data while keeping metadata.
    """
    with rasterio.open(output_raster, "w", **profile) as dest:
        for i in range(data.shape[0]):
            dest.write(data[i], i + 1)

def rotateAndDeleteEmptySpace(fileName, outputName, degreeOfRotation):
    # Open the raster .tif file
    with rasterio.open(fileName) as src:
        # Read the data from the raster (shape will be (bands, height, width))
        data = src.read()

        # Get the metadata and affine transformation
        profile = src.profile
        transform = src.transform

        cropped_bands = []
        for i in range(data.shape[0]):  # Loop over each band
            band = data[i]  # Get the i-th band
            pil_band = Image.fromarray(band)
            rotated_band = pil_band.rotate(degreeOfRotation, expand=True)
            rotated_band_data = np.array(rotated_band)
            
            # Crop empty space
            non_empty_pixels = rotated_band_data > 0
            non_empty_rows = np.any(non_empty_pixels, axis=1)
            non_empty_cols = np.any(non_empty_pixels, axis=0)
            
            min_row, max_row = np.where(non_empty_rows)[0][[0, -1]]
            min_col, max_col = np.where(non_empty_cols)[0][[0, -1]]
            
            cropped_band_data = rotated_band_data[min_row:max_row+1, min_col:max_col+1]
            cropped_bands.append(cropped_band_data)

        # Stack the cropped bands into a multi-band image
        cropped_data = np.stack(cropped_bands)

        # Update the profile and save the multi-band image
        profile.update(width=cropped_data.shape[2], height=cropped_data.shape[1])

        save_raster(outputName, cropped_data, profile)

def flip_raster(input_raster, output_raster):
    """
    Flip raster image horizontally.
    """
    with rasterio.open(input_raster) as src:
        profile = src.profile.copy()
        data = src.read()

        # Flip all bands
        flipped_data = np.array([np.fliplr(data[i]) for i in range(data.shape[0])])
        # flipped_data = np.array([np.flipud(data[i]) for i in range(data.shape[0])])

        save_raster(output_raster, flipped_data, profile)
    
def crop_raster(input_raster, output_raster, offsetRatio):
    """
    Crop a multilayer raster file to the specified bounds.
    
    Parameters:
    - input_raster: Path to the input raster file.
    - output_raster: Path to save the cropped raster file.
    - offsetRatio: crop ratio
    """
    with rasterio.open(input_raster) as src:
        # Create a geometry for the crop bounds
        bounds = src.bounds
        xOffset = (bounds.top - bounds.bottom) * offsetRatio
        yOffset = (bounds.right - bounds.left) * offsetRatio
        crop_bounds = (bounds.left + yOffset, bounds.bottom + xOffset, 
                       bounds.right - yOffset, bounds.top - xOffset)
        crop_geom = [box(*crop_bounds)]

        # Crop the raster using the geometry
        out_image, out_transform = mask(src, crop_geom, crop=True)

        # Update metadata for the new cropped raster
        out_meta = src.meta.copy()
        out_meta.update({
            "driver": "GTiff",
            "height": out_image.shape[1],
            "width": out_image.shape[2],
            "transform": out_transform,
            "dtype": src.dtypes[0],  # Preserve original dtype
            "nodata": src.nodata,  # Preserve nodata value
            "compress": src.profile.get("compress", "LZW"),  # Preserve compression
            "photometric": src.tags().get("photometric", "RGB"),  # Preserve color interpretation
        })

        save_raster(output_raster, out_image, out_meta)

def rescale_raster(input_raster, output_raster, scale_factor):
    """
    Rescale raster image (Zoom In & Out).
    """
    with rasterio.open(input_raster) as src:
        profile = src.profile.copy()
        data = src.read()

        new_h, new_w = int(data.shape[1] * scale_factor), int(data.shape[2] * scale_factor)

        # Resize each band
        rescaled_data = np.array([cv2.resize(data[i], (new_w, new_h), interpolation=cv2.INTER_LINEAR) for i in range(data.shape[0])])

        # Crop back to original size if zoomed in
        if scale_factor > 1:
            start_h, start_w = (new_h - data.shape[1]) // 2, (new_w - data.shape[2]) // 2
            rescaled_data = rescaled_data[:, start_h:start_h + data.shape[1], start_w:start_w + data.shape[2]]

        profile.update(height=data.shape[1], width=data.shape[2])

        save_raster(output_raster, rescaled_data, profile)

def getDSMFilePath(DSMMainPath):
    ''' 
    get tall the dsm file path as list
    '''
    returnData = []

    # check if the data path exist
    if(not(os.path.exists(DSMMainPath))):
        print(DSMMainPath, "path not exist")
        return DSMMainPath
    
    # loop into each main picture (day)
    for folder in os.listdir(DSMMainPath):
        folderPath = DSMMainPath + "/" + folder

        # loop into each label
        for subFolder in os.listdir(folderPath):
            subFolderPath = folderPath + "/" + subFolder

            # loop into each file
            for targetFile in os.listdir(subFolderPath):
                if(targetFile[:3] == "DSM" and targetFile[-12:] == "original.tif"):
                    targetFilePath = subFolderPath + "/" + targetFile
                    returnData.append(targetFilePath)

    return returnData

def createNewFolder(targetFilePath, foldername):
    ''' 
    create new folder for enhanced files
    '''
    prevFolderNameList = []
    
    # loop in to every target path
    for file in targetFilePath:

        # get only previouse folder path, preparing for create new folder
        prevFolderName = file.split('/')[:-1]
        prevFolderName = '/'.join(prevFolderName)

        # get rid off same files in same folder
        if(prevFolderName not in prevFolderNameList):
            prevFolderNameList.append(prevFolderName)
            
            # name new folder
            newFolderName = prevFolderName + '/' + foldername

            # check if the folder already exist
            if(not(os.path.exists(newFolderName))):
                # make new folder
                os.mkdir(newFolderName)
                print("created folder: ", newFolderName)
            else:
                print("folder already exist")

def loopAugmentDSM(dsmPathList):
    ''' 
    loop into eact dsm file for augmenttaion, save file to "Augmented" folder
    '''

    count = 0
    # loop into every dsm file
    for targetFilePath in dsmPathList:

        # create output path in Enhanced folder
        splittedPath = targetFilePath.split('/')
        prevFolderPath = splittedPath[:-1]
        outFilePath = '/'.join(prevFolderPath) + "/" + "Augmented" + "/" + splittedPath[-1][:-4]

        # correct tilt the original dsm
        # create out path for corrected tilt one outside the augment folder
        outFilePathCorrectedDegree = '/'.join(prevFolderPath) + "/" + splittedPath[-1][:-4] + "_correctedTilt.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathCorrectedDegree))):
            rotateAndDeleteEmptySpace(targetFilePath, outFilePathCorrectedDegree, 103)
        else:
            print("tilt corrected file already exist")

        # rotated, flipped, zoomed
        # create out file path for rotated
        outFilePathRotated = outFilePath + "_rotated.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathRotated))):
            rotateAndDeleteEmptySpace(outFilePathCorrectedDegree, outFilePathRotated, 180)
        else:
            print("rotated file already exist")

        # create out file path for flipped
        outFilePathFlipped = outFilePath + "_flipped.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathFlipped))):
            flip_raster(outFilePathCorrectedDegree, outFilePathFlipped)
        else:
            print("flipped file already exist")

        # create out file path for zoomed
        outFilePathZoomed = outFilePath + "_zoomed.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathZoomed))):
            crop_raster(outFilePathCorrectedDegree, outFilePathZoomed, 0.1)
        else:
            print("zoomed file already exist")

        count += 1
        print(f"finished {count} / {len(dsmPathList)} : {count*100/(len(dsmPathList)):.2f}%")

def recursiveGetRidofauxxml(folderPath):
    ''' 
    get rid of every .aux file in folder
    '''
    # loop into each file
    for file in os.listdir(folderPath):
        # assign file path
        filePath = folderPath + "/" + file
        # check if file is .aux
        if(file[-8:] == ".aux.xml"):
            # remove .aux file
            os.remove(filePath)
            print(f"removed {file}")
        
        # check if folder and call this function recursively
        if(os.path.isdir(filePath)):
            recursiveGetRidofauxxml(filePath)

# %%
dsmMainPath = "D:/ice-wheat/data/dataForProcess/mainData/DSM"
dsmPathList = getDSMFilePath(dsmMainPath)
loopAugmentDSM(dsmPathList)
# Out:
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 1 / 3565 : 0.03%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 2 / 3565 : 0.06%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3 / 3565 : 0.08%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 4 / 3565 : 0.11%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 5 / 3565 : 0.14%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 6 / 3565 : 0.17%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 7 / 3565 : 0.20%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 8 / 3565 : 0.22%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 9 / 3565 : 0.25%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 10 / 3565 : 0.28%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 11 / 3565 : 0.31%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 12 / 3565 : 0.34%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 13 / 3565 : 0.36%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 14 / 3565 : 0.39%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 15 / 3565 : 0.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 16 / 3565 : 0.45%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 17 / 3565 : 0.48%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 18 / 3565 : 0.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 19 / 3565 : 0.53%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 20 / 3565 : 0.56%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 21 / 3565 : 0.59%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 22 / 3565 : 0.62%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 23 / 3565 : 0.65%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 24 / 3565 : 0.67%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 25 / 3565 : 0.70%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 26 / 3565 : 0.73%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 27 / 3565 : 0.76%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 28 / 3565 : 0.79%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 29 / 3565 : 0.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 30 / 3565 : 0.84%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 31 / 3565 : 0.87%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 32 / 3565 : 0.90%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 33 / 3565 : 0.93%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 34 / 3565 : 0.95%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 35 / 3565 : 0.98%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 36 / 3565 : 1.01%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 37 / 3565 : 1.04%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 38 / 3565 : 1.07%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 39 / 3565 : 1.09%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 40 / 3565 : 1.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 41 / 3565 : 1.15%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 42 / 3565 : 1.18%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 43 / 3565 : 1.21%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 44 / 3565 : 1.23%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 45 / 3565 : 1.26%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 46 / 3565 : 1.29%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 47 / 3565 : 1.32%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 48 / 3565 : 1.35%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 49 / 3565 : 1.37%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 50 / 3565 : 1.40%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 51 / 3565 : 1.43%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 52 / 3565 : 1.46%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 53 / 3565 : 1.49%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 54 / 3565 : 1.51%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 55 / 3565 : 1.54%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 56 / 3565 : 1.57%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 57 / 3565 : 1.60%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 58 / 3565 : 1.63%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 59 / 3565 : 1.65%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 60 / 3565 : 1.68%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 61 / 3565 : 1.71%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 62 / 3565 : 1.74%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 63 / 3565 : 1.77%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 64 / 3565 : 1.80%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 65 / 3565 : 1.82%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 66 / 3565 : 1.85%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 67 / 3565 : 1.88%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 68 / 3565 : 1.91%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 69 / 3565 : 1.94%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 70 / 3565 : 1.96%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 71 / 3565 : 1.99%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 72 / 3565 : 2.02%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 73 / 3565 : 2.05%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 74 / 3565 : 2.08%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 75 / 3565 : 2.10%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 76 / 3565 : 2.13%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 77 / 3565 : 2.16%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 78 / 3565 : 2.19%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 79 / 3565 : 2.22%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 80 / 3565 : 2.24%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 81 / 3565 : 2.27%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 82 / 3565 : 2.30%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 83 / 3565 : 2.33%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 84 / 3565 : 2.36%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 85 / 3565 : 2.38%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 86 / 3565 : 2.41%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 87 / 3565 : 2.44%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 88 / 3565 : 2.47%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 89 / 3565 : 2.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 90 / 3565 : 2.52%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 91 / 3565 : 2.55%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 92 / 3565 : 2.58%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 93 / 3565 : 2.61%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 94 / 3565 : 2.64%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 95 / 3565 : 2.66%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 96 / 3565 : 2.69%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 97 / 3565 : 2.72%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 98 / 3565 : 2.75%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 99 / 3565 : 2.78%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 100 / 3565 : 2.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 101 / 3565 : 2.83%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 102 / 3565 : 2.86%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 103 / 3565 : 2.89%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 104 / 3565 : 2.92%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 105 / 3565 : 2.95%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 106 / 3565 : 2.97%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 107 / 3565 : 3.00%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 108 / 3565 : 3.03%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 109 / 3565 : 3.06%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 110 / 3565 : 3.09%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 111 / 3565 : 3.11%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 112 / 3565 : 3.14%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 113 / 3565 : 3.17%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 114 / 3565 : 3.20%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 115 / 3565 : 3.23%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 116 / 3565 : 3.25%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 117 / 3565 : 3.28%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 118 / 3565 : 3.31%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 119 / 3565 : 3.34%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 120 / 3565 : 3.37%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 121 / 3565 : 3.39%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 122 / 3565 : 3.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 123 / 3565 : 3.45%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 124 / 3565 : 3.48%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 125 / 3565 : 3.51%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 126 / 3565 : 3.53%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 127 / 3565 : 3.56%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 128 / 3565 : 3.59%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 129 / 3565 : 3.62%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 130 / 3565 : 3.65%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 131 / 3565 : 3.67%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 132 / 3565 : 3.70%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 133 / 3565 : 3.73%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 134 / 3565 : 3.76%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 135 / 3565 : 3.79%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 136 / 3565 : 3.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 137 / 3565 : 3.84%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 138 / 3565 : 3.87%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 139 / 3565 : 3.90%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 140 / 3565 : 3.93%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 141 / 3565 : 3.96%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 142 / 3565 : 3.98%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 143 / 3565 : 4.01%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 144 / 3565 : 4.04%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 145 / 3565 : 4.07%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 146 / 3565 : 4.10%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 147 / 3565 : 4.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 148 / 3565 : 4.15%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 149 / 3565 : 4.18%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 150 / 3565 : 4.21%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 151 / 3565 : 4.24%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 152 / 3565 : 4.26%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 153 / 3565 : 4.29%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 154 / 3565 : 4.32%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 155 / 3565 : 4.35%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 156 / 3565 : 4.38%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 157 / 3565 : 4.40%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 158 / 3565 : 4.43%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 159 / 3565 : 4.46%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 160 / 3565 : 4.49%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 161 / 3565 : 4.52%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 162 / 3565 : 4.54%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 163 / 3565 : 4.57%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 164 / 3565 : 4.60%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 165 / 3565 : 4.63%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 166 / 3565 : 4.66%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 167 / 3565 : 4.68%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 168 / 3565 : 4.71%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 169 / 3565 : 4.74%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 170 / 3565 : 4.77%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 171 / 3565 : 4.80%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 172 / 3565 : 4.82%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 173 / 3565 : 4.85%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 174 / 3565 : 4.88%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 175 / 3565 : 4.91%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 176 / 3565 : 4.94%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 177 / 3565 : 4.96%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 178 / 3565 : 4.99%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 179 / 3565 : 5.02%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 180 / 3565 : 5.05%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 181 / 3565 : 5.08%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 182 / 3565 : 5.11%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 183 / 3565 : 5.13%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 184 / 3565 : 5.16%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 185 / 3565 : 5.19%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 186 / 3565 : 5.22%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 187 / 3565 : 5.25%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 188 / 3565 : 5.27%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 189 / 3565 : 5.30%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 190 / 3565 : 5.33%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 191 / 3565 : 5.36%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 192 / 3565 : 5.39%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 193 / 3565 : 5.41%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 194 / 3565 : 5.44%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 195 / 3565 : 5.47%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 196 / 3565 : 5.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 197 / 3565 : 5.53%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 198 / 3565 : 5.55%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 199 / 3565 : 5.58%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 200 / 3565 : 5.61%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 201 / 3565 : 5.64%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 202 / 3565 : 5.67%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 203 / 3565 : 5.69%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 204 / 3565 : 5.72%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 205 / 3565 : 5.75%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 206 / 3565 : 5.78%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 207 / 3565 : 5.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 208 / 3565 : 5.83%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 209 / 3565 : 5.86%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 210 / 3565 : 5.89%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 211 / 3565 : 5.92%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 212 / 3565 : 5.95%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 213 / 3565 : 5.97%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 214 / 3565 : 6.00%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 215 / 3565 : 6.03%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 216 / 3565 : 6.06%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 217 / 3565 : 6.09%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 218 / 3565 : 6.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 219 / 3565 : 6.14%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 220 / 3565 : 6.17%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 221 / 3565 : 6.20%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 222 / 3565 : 6.23%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 223 / 3565 : 6.26%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 224 / 3565 : 6.28%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 225 / 3565 : 6.31%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 226 / 3565 : 6.34%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 227 / 3565 : 6.37%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 228 / 3565 : 6.40%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 229 / 3565 : 6.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 230 / 3565 : 6.45%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 231 / 3565 : 6.48%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 232 / 3565 : 6.51%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 233 / 3565 : 6.54%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 234 / 3565 : 6.56%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 235 / 3565 : 6.59%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 236 / 3565 : 6.62%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 237 / 3565 : 6.65%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 238 / 3565 : 6.68%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 239 / 3565 : 6.70%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 240 / 3565 : 6.73%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 241 / 3565 : 6.76%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 242 / 3565 : 6.79%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 243 / 3565 : 6.82%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 244 / 3565 : 6.84%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 245 / 3565 : 6.87%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 246 / 3565 : 6.90%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 247 / 3565 : 6.93%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 248 / 3565 : 6.96%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 249 / 3565 : 6.98%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 250 / 3565 : 7.01%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 251 / 3565 : 7.04%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 252 / 3565 : 7.07%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 253 / 3565 : 7.10%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 254 / 3565 : 7.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 255 / 3565 : 7.15%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 256 / 3565 : 7.18%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 257 / 3565 : 7.21%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 258 / 3565 : 7.24%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 259 / 3565 : 7.27%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 260 / 3565 : 7.29%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 261 / 3565 : 7.32%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 262 / 3565 : 7.35%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 263 / 3565 : 7.38%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 264 / 3565 : 7.41%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 265 / 3565 : 7.43%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 266 / 3565 : 7.46%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 267 / 3565 : 7.49%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 268 / 3565 : 7.52%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 269 / 3565 : 7.55%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 270 / 3565 : 7.57%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 271 / 3565 : 7.60%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 272 / 3565 : 7.63%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 273 / 3565 : 7.66%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 274 / 3565 : 7.69%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 275 / 3565 : 7.71%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 276 / 3565 : 7.74%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 277 / 3565 : 7.77%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 278 / 3565 : 7.80%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 279 / 3565 : 7.83%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 280 / 3565 : 7.85%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 281 / 3565 : 7.88%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 282 / 3565 : 7.91%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 283 / 3565 : 7.94%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 284 / 3565 : 7.97%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 285 / 3565 : 7.99%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 286 / 3565 : 8.02%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 287 / 3565 : 8.05%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 288 / 3565 : 8.08%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 289 / 3565 : 8.11%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 290 / 3565 : 8.13%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 291 / 3565 : 8.16%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 292 / 3565 : 8.19%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 293 / 3565 : 8.22%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 294 / 3565 : 8.25%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 295 / 3565 : 8.27%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 296 / 3565 : 8.30%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 297 / 3565 : 8.33%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 298 / 3565 : 8.36%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 299 / 3565 : 8.39%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 300 / 3565 : 8.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 301 / 3565 : 8.44%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 302 / 3565 : 8.47%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 303 / 3565 : 8.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 304 / 3565 : 8.53%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 305 / 3565 : 8.56%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 306 / 3565 : 8.58%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 307 / 3565 : 8.61%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 308 / 3565 : 8.64%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 309 / 3565 : 8.67%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 310 / 3565 : 8.70%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 311 / 3565 : 8.72%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 312 / 3565 : 8.75%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 313 / 3565 : 8.78%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 314 / 3565 : 8.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 315 / 3565 : 8.84%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 316 / 3565 : 8.86%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 317 / 3565 : 8.89%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 318 / 3565 : 8.92%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 319 / 3565 : 8.95%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 320 / 3565 : 8.98%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 321 / 3565 : 9.00%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 322 / 3565 : 9.03%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 323 / 3565 : 9.06%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 324 / 3565 : 9.09%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 325 / 3565 : 9.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 326 / 3565 : 9.14%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 327 / 3565 : 9.17%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 328 / 3565 : 9.20%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 329 / 3565 : 9.23%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 330 / 3565 : 9.26%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 331 / 3565 : 9.28%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 332 / 3565 : 9.31%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 333 / 3565 : 9.34%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 334 / 3565 : 9.37%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 335 / 3565 : 9.40%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 336 / 3565 : 9.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 337 / 3565 : 9.45%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 338 / 3565 : 9.48%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# ...
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3455 / 3565 : 96.91%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3456 / 3565 : 96.94%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3457 / 3565 : 96.97%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3458 / 3565 : 97.00%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3459 / 3565 : 97.03%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3460 / 3565 : 97.05%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3461 / 3565 : 97.08%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3462 / 3565 : 97.11%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3463 / 3565 : 97.14%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3464 / 3565 : 97.17%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3465 / 3565 : 97.19%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3466 / 3565 : 97.22%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3467 / 3565 : 97.25%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3468 / 3565 : 97.28%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3469 / 3565 : 97.31%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3470 / 3565 : 97.34%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3471 / 3565 : 97.36%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3472 / 3565 : 97.39%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3473 / 3565 : 97.42%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3474 / 3565 : 97.45%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3475 / 3565 : 97.48%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3476 / 3565 : 97.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3477 / 3565 : 97.53%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3478 / 3565 : 97.56%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3479 / 3565 : 97.59%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3480 / 3565 : 97.62%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3481 / 3565 : 97.64%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3482 / 3565 : 97.67%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3483 / 3565 : 97.70%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3484 / 3565 : 97.73%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3485 / 3565 : 97.76%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3486 / 3565 : 97.78%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3487 / 3565 : 97.81%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3488 / 3565 : 97.84%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3489 / 3565 : 97.87%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3490 / 3565 : 97.90%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3491 / 3565 : 97.92%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3492 / 3565 : 97.95%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3493 / 3565 : 97.98%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3494 / 3565 : 98.01%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3495 / 3565 : 98.04%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3496 / 3565 : 98.06%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3497 / 3565 : 98.09%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3498 / 3565 : 98.12%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3499 / 3565 : 98.15%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3500 / 3565 : 98.18%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3501 / 3565 : 98.20%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3502 / 3565 : 98.23%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3503 / 3565 : 98.26%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3504 / 3565 : 98.29%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3505 / 3565 : 98.32%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3506 / 3565 : 98.35%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3507 / 3565 : 98.37%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3508 / 3565 : 98.40%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3509 / 3565 : 98.43%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3510 / 3565 : 98.46%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3511 / 3565 : 98.49%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3512 / 3565 : 98.51%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3513 / 3565 : 98.54%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3514 / 3565 : 98.57%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3515 / 3565 : 98.60%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3516 / 3565 : 98.63%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3517 / 3565 : 98.65%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3518 / 3565 : 98.68%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3519 / 3565 : 98.71%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3520 / 3565 : 98.74%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3521 / 3565 : 98.77%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3522 / 3565 : 98.79%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3523 / 3565 : 98.82%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3524 / 3565 : 98.85%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3525 / 3565 : 98.88%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3526 / 3565 : 98.91%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3527 / 3565 : 98.93%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3528 / 3565 : 98.96%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3529 / 3565 : 98.99%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3530 / 3565 : 99.02%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3531 / 3565 : 99.05%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3532 / 3565 : 99.07%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3533 / 3565 : 99.10%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3534 / 3565 : 99.13%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3535 / 3565 : 99.16%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3536 / 3565 : 99.19%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3537 / 3565 : 99.21%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3538 / 3565 : 99.24%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3539 / 3565 : 99.27%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3540 / 3565 : 99.30%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3541 / 3565 : 99.33%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3542 / 3565 : 99.35%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3543 / 3565 : 99.38%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3544 / 3565 : 99.41%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3545 / 3565 : 99.44%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3546 / 3565 : 99.47%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3547 / 3565 : 99.50%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3548 / 3565 : 99.52%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3549 / 3565 : 99.55%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3550 / 3565 : 99.58%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3551 / 3565 : 99.61%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3552 / 3565 : 99.64%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3553 / 3565 : 99.66%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3554 / 3565 : 99.69%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3555 / 3565 : 99.72%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3556 / 3565 : 99.75%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3557 / 3565 : 99.78%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3558 / 3565 : 99.80%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3559 / 3565 : 99.83%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3560 / 3565 : 99.86%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3561 / 3565 : 99.89%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3562 / 3565 : 99.92%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3563 / 3565 : 99.94%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3564 / 3565 : 99.97%
# tilt corrected file already exist
# rotated file already exist
# flipped file already exist
# zoomed file already exist
# finished 3565 / 3565 : 100.00%

# %%
recursiveGetRidofauxxml("/Volumes/HD-PCFSU3-A/ice-wheat/data/dataForProcess/mainData")
# Out:
# removed DSM_202402131116_7_original_correctedTilt.tif.aux.xml
# removed RGB_202402131116_7_original.jpg.aux.xml
