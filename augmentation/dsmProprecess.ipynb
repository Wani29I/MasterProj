# %%
import os
import cv2
import random
import rasterio
import numpy as np
from PIL import Image, ImageEnhance
import geopandas as gpd
from rasterio.mask import mask
from rasterio.plot import show
import matplotlib.pyplot as plt
from shapely.geometry import box
from rasterio.windows import Window

# %%
def save_raster(output_raster, data, profile):
    """
    Save raster data while keeping metadata.
    """
    with rasterio.open(output_raster, "w", **profile) as dest:
        for i in range(data.shape[0]):
            dest.write(data[i], i + 1)

def rotateAndDeleteEmptySpace(fileName, outputName, degreeOfRotation):
    # Open the raster .tif file
    with rasterio.open(fileName) as src:
        # Read the data from the raster (shape will be (bands, height, width))
        data = src.read()

        # Get the metadata and affine transformation
        profile = src.profile
        transform = src.transform

        cropped_bands = []
        for i in range(data.shape[0]):  # Loop over each band
            band = data[i]  # Get the i-th band
            pil_band = Image.fromarray(band)
            rotated_band = pil_band.rotate(degreeOfRotation, expand=True)
            rotated_band_data = np.array(rotated_band)
            
            # Crop empty space
            non_empty_pixels = rotated_band_data > 0
            non_empty_rows = np.any(non_empty_pixels, axis=1)
            non_empty_cols = np.any(non_empty_pixels, axis=0)
            
            min_row, max_row = np.where(non_empty_rows)[0][[0, -1]]
            min_col, max_col = np.where(non_empty_cols)[0][[0, -1]]
            
            cropped_band_data = rotated_band_data[min_row:max_row+1, min_col:max_col+1]
            cropped_bands.append(cropped_band_data)

        # Stack the cropped bands into a multi-band image
        cropped_data = np.stack(cropped_bands)

        # Update the profile and save the multi-band image
        profile.update(width=cropped_data.shape[2], height=cropped_data.shape[1])

        save_raster(outputName, cropped_data, profile)

def flip_raster(input_raster, output_raster):
    """
    Flip raster image horizontally.
    """
    with rasterio.open(input_raster) as src:
        profile = src.profile.copy()
        data = src.read()

        # Flip all bands
        flipped_data = np.array([np.fliplr(data[i]) for i in range(data.shape[0])])
        # flipped_data = np.array([np.flipud(data[i]) for i in range(data.shape[0])])

        save_raster(output_raster, flipped_data, profile)
    
def crop_raster(input_raster, output_raster, offsetRatio):
    """
    Crop a multilayer raster file to the specified bounds.
    
    Parameters:
    - input_raster: Path to the input raster file.
    - output_raster: Path to save the cropped raster file.
    - offsetRatio: crop ratio
    """
    with rasterio.open(input_raster) as src:
        # Create a geometry for the crop bounds
        bounds = src.bounds
        xOffset = (bounds.top - bounds.bottom) * offsetRatio
        yOffset = (bounds.right - bounds.left) * offsetRatio
        crop_bounds = (bounds.left + yOffset, bounds.bottom + xOffset, 
                       bounds.right - yOffset, bounds.top - xOffset)
        crop_geom = [box(*crop_bounds)]

        # Crop the raster using the geometry
        out_image, out_transform = mask(src, crop_geom, crop=True)

        # Update metadata for the new cropped raster
        out_meta = src.meta.copy()
        out_meta.update({
            "driver": "GTiff",
            "height": out_image.shape[1],
            "width": out_image.shape[2],
            "transform": out_transform,
            "dtype": src.dtypes[0],  # Preserve original dtype
            "nodata": src.nodata,  # Preserve nodata value
            "compress": src.profile.get("compress", "LZW"),  # Preserve compression
            "photometric": src.tags().get("photometric", "RGB"),  # Preserve color interpretation
        })

        save_raster(output_raster, out_image, out_meta)

def rescale_raster(input_raster, output_raster, scale_factor):
    """
    Rescale raster image (Zoom In & Out).
    """
    with rasterio.open(input_raster) as src:
        profile = src.profile.copy()
        data = src.read()

        new_h, new_w = int(data.shape[1] * scale_factor), int(data.shape[2] * scale_factor)

        # Resize each band
        rescaled_data = np.array([cv2.resize(data[i], (new_w, new_h), interpolation=cv2.INTER_LINEAR) for i in range(data.shape[0])])

        # Crop back to original size if zoomed in
        if scale_factor > 1:
            start_h, start_w = (new_h - data.shape[1]) // 2, (new_w - data.shape[2]) // 2
            rescaled_data = rescaled_data[:, start_h:start_h + data.shape[1], start_w:start_w + data.shape[2]]

        profile.update(height=data.shape[1], width=data.shape[2])

        save_raster(output_raster, rescaled_data, profile)

def getDSMFilePath(DSMMainPath):
    ''' 
    get tall the dsm file path as list
    '''
    returnData = []

    # check if the data path exist
    if(not(os.path.exists(DSMMainPath))):
        print(DSMMainPath, "path not exist")
        return DSMMainPath
    
    # loop into each main picture (day)
    for folder in os.listdir(DSMMainPath):
        folderPath = DSMMainPath + "/" + folder

        # loop into each label
        for subFolder in os.listdir(folderPath):
            subFolderPath = folderPath + "/" + subFolder

            # loop into each file
            for targetFile in os.listdir(subFolderPath):
                if(targetFile[:3] == "DSM" and targetFile[-12:] == "original.tif"):
                    targetFilePath = subFolderPath + "/" + targetFile
                    returnData.append(targetFilePath)

    return returnData

def createNewFolder(targetFilePath, foldername):
    ''' 
    create new folder for enhanced files
    '''
    prevFolderNameList = []
    
    # loop in to every target path
    for file in targetFilePath:

        # get only previouse folder path, preparing for create new folder
        prevFolderName = file.split('/')[:-1]
        prevFolderName = '/'.join(prevFolderName)

        # get rid off same files in same folder
        if(prevFolderName not in prevFolderNameList):
            prevFolderNameList.append(prevFolderName)
            
            # name new folder
            newFolderName = prevFolderName + '/' + foldername

            # check if the folder already exist
            if(not(os.path.exists(newFolderName))):
                # make new folder
                os.mkdir(newFolderName)
                print("created folder: ", newFolderName)
            else:
                print("folder already exist")

def loopAugmentDSM(dsmPathList):
    ''' 
    loop into eact dsm file for augmenttaion, save file to "Augmented" folder
    '''

    count = 0
    # loop into every dsm file
    for targetFilePath in dsmPathList:

        # create output path in Enhanced folder
        splittedPath = targetFilePath.split('/')
        prevFolderPath = splittedPath[:-1]
        outFilePath = '/'.join(prevFolderPath) + "/" + "Augmented" + "/" + splittedPath[-1][:-4]

        # correct tilt the original dsm
        # create out path for corrected tilt one outside the augment folder
        outFilePathCorrectedDegree = '/'.join(prevFolderPath) + "/" + splittedPath[-1][:-4] + "_correctedTilt.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathCorrectedDegree))):
            print("tilt corrected file not exist: ", outFilePathCorrectedDegree)
            rotateAndDeleteEmptySpace(targetFilePath, outFilePathCorrectedDegree, 24)
        else:
            print("tilt corrected file already exist")

        augmentedFolderPath = '/'.join(prevFolderPath) + "/" + "Augmented"
        # print(augmentedFolderPath)
        # check if the folder already exist
        if(not(os.path.exists(augmentedFolderPath))):
            # make new folder
            os.mkdir(augmentedFolderPath)
            print("created folder: ", augmentedFolderPath)
        else:
            print("folder already exist")

        # rotated, flipped, zoomed
        # create out file path for rotated
        outFilePathRotated = outFilePath + "_rotated.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathRotated))):
            rotateAndDeleteEmptySpace(outFilePathCorrectedDegree, outFilePathRotated, 180)
        else:
            print("rotated file already exist")

        # create out file path for flipped
        outFilePathFlipped = outFilePath + "_flipped.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathFlipped))):
            flip_raster(outFilePathCorrectedDegree, outFilePathFlipped)
        else:
            print("flipped file already exist")

        # create out file path for zoomed
        outFilePathZoomed = outFilePath + "_zoomed.tif"
        # check if file not already exist
        if(not(os.path.exists(outFilePathZoomed))):
            crop_raster(outFilePathCorrectedDegree, outFilePathZoomed, 0.1)
        else:
            print("zoomed file already exist")

        count += 1
        print(f"finished {count} / {len(dsmPathList)} : {count*100/(len(dsmPathList)):.2f}%")

def recursiveGetRidofauxxml(folderPath):
    ''' 
    get rid of every .aux file in folder
    '''
    # loop into each file
    for file in os.listdir(folderPath):
        # assign file path
        filePath = folderPath + "/" + file
        # check if file is .aux
        if(file[-8:] == ".aux.xml"):
            # remove .aux file
            os.remove(filePath)
            print(f"removed {file}")
        
        # check if folder and call this function recursively
        if(os.path.isdir(filePath)):
            recursiveGetRidofauxxml(filePath)

# %%
dsmMainPath = "/Volumes/PortableSSD/dataForProcess/2025MainData/DSM"
dsmPathList = getDSMFilePath(dsmMainPath)
loopAugmentDSM(dsmPathList)
# Out:
# tilt corrected file already exist
# folder already exist
# finished 1 / 960 : 0.10%
# tilt corrected file already exist
# folder already exist
# finished 2 / 960 : 0.21%
# tilt corrected file already exist
# folder already exist
# finished 3 / 960 : 0.31%
# tilt corrected file already exist
# folder already exist
# finished 4 / 960 : 0.42%
# tilt corrected file already exist
# folder already exist
# finished 5 / 960 : 0.52%
# tilt corrected file already exist
# folder already exist
# finished 6 / 960 : 0.62%
# tilt corrected file already exist
# folder already exist
# finished 7 / 960 : 0.73%
# tilt corrected file already exist
# folder already exist
# finished 8 / 960 : 0.83%
# tilt corrected file already exist
# folder already exist
# finished 9 / 960 : 0.94%
# tilt corrected file already exist
# folder already exist
# finished 10 / 960 : 1.04%
# tilt corrected file already exist
# folder already exist
# finished 11 / 960 : 1.15%
# tilt corrected file already exist
# folder already exist
# finished 12 / 960 : 1.25%
# tilt corrected file already exist
# folder already exist
# finished 13 / 960 : 1.35%
# tilt corrected file already exist
# folder already exist
# finished 14 / 960 : 1.46%
# tilt corrected file already exist
# folder already exist
# finished 15 / 960 : 1.56%
# tilt corrected file already exist
# folder already exist
# finished 16 / 960 : 1.67%
# tilt corrected file already exist
# folder already exist
# finished 17 / 960 : 1.77%
# tilt corrected file already exist
# folder already exist
# finished 18 / 960 : 1.88%
# tilt corrected file already exist
# folder already exist
# finished 19 / 960 : 1.98%
# tilt corrected file already exist
# folder already exist
# finished 20 / 960 : 2.08%
# tilt corrected file already exist
# folder already exist
# finished 21 / 960 : 2.19%
# tilt corrected file already exist
# folder already exist
# finished 22 / 960 : 2.29%
# tilt corrected file already exist
# folder already exist
# finished 23 / 960 : 2.40%
# tilt corrected file already exist
# folder already exist
# finished 24 / 960 : 2.50%
# tilt corrected file already exist
# folder already exist
# finished 25 / 960 : 2.60%
# tilt corrected file already exist
# folder already exist
# finished 26 / 960 : 2.71%
# tilt corrected file already exist
# folder already exist
# finished 27 / 960 : 2.81%
# tilt corrected file already exist
# folder already exist
# finished 28 / 960 : 2.92%
# tilt corrected file already exist
# folder already exist
# finished 29 / 960 : 3.02%
# tilt corrected file already exist
# folder already exist
# finished 30 / 960 : 3.12%
# tilt corrected file already exist
# folder already exist
# finished 31 / 960 : 3.23%
# tilt corrected file already exist
# folder already exist
# finished 32 / 960 : 3.33%
# tilt corrected file already exist
# folder already exist
# finished 33 / 960 : 3.44%
# tilt corrected file already exist
# folder already exist
# finished 34 / 960 : 3.54%
# tilt corrected file already exist
# folder already exist
# finished 35 / 960 : 3.65%
# tilt corrected file already exist
# folder already exist
# finished 36 / 960 : 3.75%
# tilt corrected file already exist
# folder already exist
# finished 37 / 960 : 3.85%
# tilt corrected file already exist
# folder already exist
# finished 38 / 960 : 3.96%
# tilt corrected file already exist
# folder already exist
# finished 39 / 960 : 4.06%
# tilt corrected file already exist
# folder already exist
# finished 40 / 960 : 4.17%
# tilt corrected file already exist
# folder already exist
# finished 41 / 960 : 4.27%
# tilt corrected file already exist
# folder already exist
# finished 42 / 960 : 4.38%
# tilt corrected file already exist
# folder already exist
# finished 43 / 960 : 4.48%
# tilt corrected file already exist
# folder already exist
# finished 44 / 960 : 4.58%
# tilt corrected file already exist
# folder already exist
# finished 45 / 960 : 4.69%
# tilt corrected file already exist
# folder already exist
# finished 46 / 960 : 4.79%
# tilt corrected file already exist
# folder already exist
# finished 47 / 960 : 4.90%
# tilt corrected file already exist
# folder already exist
# finished 48 / 960 : 5.00%
# tilt corrected file already exist
# folder already exist
# finished 49 / 960 : 5.10%
# tilt corrected file already exist
# folder already exist
# finished 50 / 960 : 5.21%
# tilt corrected file already exist
# folder already exist
# finished 51 / 960 : 5.31%
# tilt corrected file already exist
# folder already exist
# finished 52 / 960 : 5.42%
# tilt corrected file already exist
# folder already exist
# finished 53 / 960 : 5.52%
# tilt corrected file already exist
# folder already exist
# finished 54 / 960 : 5.62%
# tilt corrected file already exist
# folder already exist
# finished 55 / 960 : 5.73%
# tilt corrected file already exist
# folder already exist
# finished 56 / 960 : 5.83%
# tilt corrected file already exist
# folder already exist
# finished 57 / 960 : 5.94%
# tilt corrected file already exist
# folder already exist
# finished 58 / 960 : 6.04%
# tilt corrected file already exist
# folder already exist
# finished 59 / 960 : 6.15%
# tilt corrected file already exist
# folder already exist
# finished 60 / 960 : 6.25%
# tilt corrected file already exist
# folder already exist
# finished 61 / 960 : 6.35%
# tilt corrected file already exist
# folder already exist
# finished 62 / 960 : 6.46%
# tilt corrected file already exist
# folder already exist
# finished 63 / 960 : 6.56%
# tilt corrected file already exist
# folder already exist
# finished 64 / 960 : 6.67%
# tilt corrected file already exist
# folder already exist
# finished 65 / 960 : 6.77%
# tilt corrected file already exist
# folder already exist
# finished 66 / 960 : 6.88%
# tilt corrected file already exist
# folder already exist
# finished 67 / 960 : 6.98%
# tilt corrected file already exist
# folder already exist
# finished 68 / 960 : 7.08%
# tilt corrected file already exist
# folder already exist
# finished 69 / 960 : 7.19%
# tilt corrected file already exist
# folder already exist
# finished 70 / 960 : 7.29%
# tilt corrected file already exist
# folder already exist
# finished 71 / 960 : 7.40%
# tilt corrected file already exist
# folder already exist
# finished 72 / 960 : 7.50%
# tilt corrected file already exist
# folder already exist
# finished 73 / 960 : 7.60%
# tilt corrected file already exist
# folder already exist
# finished 74 / 960 : 7.71%
# tilt corrected file already exist
# folder already exist
# finished 75 / 960 : 7.81%
# tilt corrected file already exist
# folder already exist
# finished 76 / 960 : 7.92%
# tilt corrected file already exist
# folder already exist
# finished 77 / 960 : 8.02%
# tilt corrected file already exist
# folder already exist
# finished 78 / 960 : 8.12%
# tilt corrected file already exist
# folder already exist
# finished 79 / 960 : 8.23%
# tilt corrected file already exist
# folder already exist
# finished 80 / 960 : 8.33%
# tilt corrected file already exist
# folder already exist
# finished 81 / 960 : 8.44%
# tilt corrected file already exist
# folder already exist
# finished 82 / 960 : 8.54%
# tilt corrected file already exist
# folder already exist
# finished 83 / 960 : 8.65%
# tilt corrected file already exist
# folder already exist
# finished 84 / 960 : 8.75%
# tilt corrected file already exist
# folder already exist
# finished 85 / 960 : 8.85%
# tilt corrected file already exist
# folder already exist
# finished 86 / 960 : 8.96%
# tilt corrected file already exist
# folder already exist
# finished 87 / 960 : 9.06%
# tilt corrected file already exist
# folder already exist
# finished 88 / 960 : 9.17%
# tilt corrected file already exist
# folder already exist
# finished 89 / 960 : 9.27%
# tilt corrected file already exist
# folder already exist
# finished 90 / 960 : 9.38%
# tilt corrected file already exist
# folder already exist
# finished 91 / 960 : 9.48%
# tilt corrected file already exist
# folder already exist
# finished 92 / 960 : 9.58%
# tilt corrected file already exist
# folder already exist
# finished 93 / 960 : 9.69%
# tilt corrected file already exist
# folder already exist
# finished 94 / 960 : 9.79%
# tilt corrected file already exist
# folder already exist
# finished 95 / 960 : 9.90%
# tilt corrected file already exist
# folder already exist
# finished 96 / 960 : 10.00%
# tilt corrected file already exist
# folder already exist
# finished 97 / 960 : 10.10%
# tilt corrected file already exist
# folder already exist
# finished 98 / 960 : 10.21%
# tilt corrected file already exist
# folder already exist
# finished 99 / 960 : 10.31%
# tilt corrected file already exist
# folder already exist
# finished 100 / 960 : 10.42%
# tilt corrected file already exist
# folder already exist
# finished 101 / 960 : 10.52%
# tilt corrected file already exist
# folder already exist
# finished 102 / 960 : 10.62%
# tilt corrected file already exist
# folder already exist
# finished 103 / 960 : 10.73%
# tilt corrected file already exist
# folder already exist
# finished 104 / 960 : 10.83%
# tilt corrected file already exist
# folder already exist
# finished 105 / 960 : 10.94%
# tilt corrected file already exist
# folder already exist
# finished 106 / 960 : 11.04%
# tilt corrected file already exist
# folder already exist
# finished 107 / 960 : 11.15%
# tilt corrected file already exist
# folder already exist
# finished 108 / 960 : 11.25%
# tilt corrected file already exist
# folder already exist
# finished 109 / 960 : 11.35%
# tilt corrected file already exist
# folder already exist
# finished 110 / 960 : 11.46%
# tilt corrected file already exist
# folder already exist
# finished 111 / 960 : 11.56%
# tilt corrected file already exist
# folder already exist
# finished 112 / 960 : 11.67%
# tilt corrected file already exist
# folder already exist
# finished 113 / 960 : 11.77%
# tilt corrected file already exist
# folder already exist
# finished 114 / 960 : 11.88%
# tilt corrected file already exist
# folder already exist
# finished 115 / 960 : 11.98%
# tilt corrected file already exist
# folder already exist
# finished 116 / 960 : 12.08%
# tilt corrected file already exist
# folder already exist
# finished 117 / 960 : 12.19%
# tilt corrected file already exist
# folder already exist
# finished 118 / 960 : 12.29%
# tilt corrected file already exist
# folder already exist
# finished 119 / 960 : 12.40%
# tilt corrected file already exist
# folder already exist
# finished 120 / 960 : 12.50%
# tilt corrected file already exist
# folder already exist
# finished 121 / 960 : 12.60%
# tilt corrected file already exist
# folder already exist
# finished 122 / 960 : 12.71%
# tilt corrected file already exist
# folder already exist
# finished 123 / 960 : 12.81%
# tilt corrected file already exist
# folder already exist
# finished 124 / 960 : 12.92%
# tilt corrected file already exist
# folder already exist
# finished 125 / 960 : 13.02%
# tilt corrected file already exist
# folder already exist
# finished 126 / 960 : 13.12%
# tilt corrected file already exist
# folder already exist
# finished 127 / 960 : 13.23%
# tilt corrected file already exist
# folder already exist
# finished 128 / 960 : 13.33%
# tilt corrected file already exist
# folder already exist
# finished 129 / 960 : 13.44%
# tilt corrected file already exist
# folder already exist
# finished 130 / 960 : 13.54%
# tilt corrected file already exist
# folder already exist
# finished 131 / 960 : 13.65%
# tilt corrected file already exist
# folder already exist
# finished 132 / 960 : 13.75%
# tilt corrected file already exist
# folder already exist
# finished 133 / 960 : 13.85%
# tilt corrected file already exist
# folder already exist
# finished 134 / 960 : 13.96%
# tilt corrected file already exist
# folder already exist
# finished 135 / 960 : 14.06%
# tilt corrected file already exist
# folder already exist
# finished 136 / 960 : 14.17%
# tilt corrected file already exist
# folder already exist
# finished 137 / 960 : 14.27%
# tilt corrected file already exist
# folder already exist
# finished 138 / 960 : 14.38%
# tilt corrected file already exist
# folder already exist
# finished 139 / 960 : 14.48%
# tilt corrected file already exist
# folder already exist
# finished 140 / 960 : 14.58%
# tilt corrected file already exist
# folder already exist
# finished 141 / 960 : 14.69%
# tilt corrected file already exist
# folder already exist
# finished 142 / 960 : 14.79%
# tilt corrected file already exist
# folder already exist
# finished 143 / 960 : 14.90%
# tilt corrected file already exist
# folder already exist
# finished 144 / 960 : 15.00%
# tilt corrected file already exist
# folder already exist
# finished 145 / 960 : 15.10%
# tilt corrected file already exist
# folder already exist
# finished 146 / 960 : 15.21%
# tilt corrected file already exist
# folder already exist
# finished 147 / 960 : 15.31%
# tilt corrected file already exist
# folder already exist
# finished 148 / 960 : 15.42%
# tilt corrected file already exist
# folder already exist
# finished 149 / 960 : 15.52%
# tilt corrected file already exist
# folder already exist
# finished 150 / 960 : 15.62%
# tilt corrected file already exist
# folder already exist
# finished 151 / 960 : 15.73%
# tilt corrected file already exist
# folder already exist
# finished 152 / 960 : 15.83%
# tilt corrected file already exist
# folder already exist
# finished 153 / 960 : 15.94%
# tilt corrected file already exist
# folder already exist
# finished 154 / 960 : 16.04%
# tilt corrected file already exist
# folder already exist
# finished 155 / 960 : 16.15%
# tilt corrected file already exist
# folder already exist
# finished 156 / 960 : 16.25%
# tilt corrected file already exist
# folder already exist
# finished 157 / 960 : 16.35%
# tilt corrected file already exist
# folder already exist
# finished 158 / 960 : 16.46%
# tilt corrected file already exist
# folder already exist
# finished 159 / 960 : 16.56%
# tilt corrected file already exist
# folder already exist
# finished 160 / 960 : 16.67%
# tilt corrected file already exist
# folder already exist
# finished 161 / 960 : 16.77%
# tilt corrected file already exist
# folder already exist
# finished 162 / 960 : 16.88%
# tilt corrected file already exist
# folder already exist
# finished 163 / 960 : 16.98%
# tilt corrected file already exist
# folder already exist
# finished 164 / 960 : 17.08%
# tilt corrected file already exist
# folder already exist
# finished 165 / 960 : 17.19%
# tilt corrected file already exist
# folder already exist
# finished 166 / 960 : 17.29%
# tilt corrected file already exist
# folder already exist
# finished 167 / 960 : 17.40%
# tilt corrected file already exist
# folder already exist
# finished 168 / 960 : 17.50%
# tilt corrected file already exist
# folder already exist
# finished 169 / 960 : 17.60%
# tilt corrected file already exist
# folder already exist
# finished 170 / 960 : 17.71%
# tilt corrected file already exist
# folder already exist
# finished 171 / 960 : 17.81%
# tilt corrected file already exist
# folder already exist
# finished 172 / 960 : 17.92%
# tilt corrected file already exist
# folder already exist
# finished 173 / 960 : 18.02%
# tilt corrected file already exist
# folder already exist
# finished 174 / 960 : 18.12%
# tilt corrected file already exist
# folder already exist
# finished 175 / 960 : 18.23%
# tilt corrected file already exist
# folder already exist
# finished 176 / 960 : 18.33%
# tilt corrected file already exist
# folder already exist
# finished 177 / 960 : 18.44%
# tilt corrected file already exist
# folder already exist
# finished 178 / 960 : 18.54%
# tilt corrected file already exist
# folder already exist
# finished 179 / 960 : 18.65%
# tilt corrected file already exist
# folder already exist
# finished 180 / 960 : 18.75%
# tilt corrected file already exist
# folder already exist
# finished 181 / 960 : 18.85%
# tilt corrected file already exist
# folder already exist
# finished 182 / 960 : 18.96%
# tilt corrected file already exist
# folder already exist
# finished 183 / 960 : 19.06%
# tilt corrected file already exist
# folder already exist
# finished 184 / 960 : 19.17%
# tilt corrected file already exist
# folder already exist
# finished 185 / 960 : 19.27%
# tilt corrected file already exist
# folder already exist
# finished 186 / 960 : 19.38%
# tilt corrected file already exist
# folder already exist
# finished 187 / 960 : 19.48%
# tilt corrected file already exist
# folder already exist
# finished 188 / 960 : 19.58%
# tilt corrected file already exist
# folder already exist
# finished 189 / 960 : 19.69%
# tilt corrected file already exist
# folder already exist
# finished 190 / 960 : 19.79%
# tilt corrected file already exist
# folder already exist
# finished 191 / 960 : 19.90%
# tilt corrected file already exist
# folder already exist
# finished 192 / 960 : 20.00%
# tilt corrected file already exist
# folder already exist
# finished 193 / 960 : 20.10%
# tilt corrected file already exist
# folder already exist
# finished 194 / 960 : 20.21%
# tilt corrected file already exist
# folder already exist
# finished 195 / 960 : 20.31%
# tilt corrected file already exist
# folder already exist
# finished 196 / 960 : 20.42%
# tilt corrected file already exist
# folder already exist
# finished 197 / 960 : 20.52%
# tilt corrected file already exist
# folder already exist
# finished 198 / 960 : 20.62%
# tilt corrected file already exist
# folder already exist
# finished 199 / 960 : 20.73%
# tilt corrected file already exist
# folder already exist
# finished 200 / 960 : 20.83%
# tilt corrected file already exist
# folder already exist
# finished 201 / 960 : 20.94%
# tilt corrected file already exist
# folder already exist
# finished 202 / 960 : 21.04%
# tilt corrected file already exist
# folder already exist
# finished 203 / 960 : 21.15%
# tilt corrected file already exist
# folder already exist
# finished 204 / 960 : 21.25%
# tilt corrected file already exist
# folder already exist
# finished 205 / 960 : 21.35%
# tilt corrected file already exist
# folder already exist
# finished 206 / 960 : 21.46%
# tilt corrected file already exist
# folder already exist
# finished 207 / 960 : 21.56%
# tilt corrected file already exist
# folder already exist
# finished 208 / 960 : 21.67%
# tilt corrected file already exist
# folder already exist
# finished 209 / 960 : 21.77%
# tilt corrected file already exist
# folder already exist
# finished 210 / 960 : 21.88%
# tilt corrected file already exist
# folder already exist
# finished 211 / 960 : 21.98%
# tilt corrected file already exist
# folder already exist
# finished 212 / 960 : 22.08%
# tilt corrected file already exist
# folder already exist
# finished 213 / 960 : 22.19%
# tilt corrected file already exist
# folder already exist
# finished 214 / 960 : 22.29%
# tilt corrected file already exist
# folder already exist
# finished 215 / 960 : 22.40%
# tilt corrected file already exist
# folder already exist
# finished 216 / 960 : 22.50%
# tilt corrected file already exist
# folder already exist
# finished 217 / 960 : 22.60%
# tilt corrected file already exist
# folder already exist
# finished 218 / 960 : 22.71%
# tilt corrected file already exist
# folder already exist
# finished 219 / 960 : 22.81%
# tilt corrected file already exist
# folder already exist
# finished 220 / 960 : 22.92%
# tilt corrected file already exist
# folder already exist
# finished 221 / 960 : 23.02%
# tilt corrected file already exist
# folder already exist
# finished 222 / 960 : 23.12%
# tilt corrected file already exist
# folder already exist
# finished 223 / 960 : 23.23%
# tilt corrected file already exist
# folder already exist
# finished 224 / 960 : 23.33%
# tilt corrected file already exist
# folder already exist
# finished 225 / 960 : 23.44%
# tilt corrected file already exist
# folder already exist
# finished 226 / 960 : 23.54%
# tilt corrected file already exist
# folder already exist
# finished 227 / 960 : 23.65%
# tilt corrected file already exist
# folder already exist
# finished 228 / 960 : 23.75%
# tilt corrected file already exist
# folder already exist
# finished 229 / 960 : 23.85%
# tilt corrected file already exist
# folder already exist
# finished 230 / 960 : 23.96%
# tilt corrected file already exist
# folder already exist
# finished 231 / 960 : 24.06%
# tilt corrected file already exist
# folder already exist
# finished 232 / 960 : 24.17%
# tilt corrected file already exist
# folder already exist
# finished 233 / 960 : 24.27%
# tilt corrected file already exist
# folder already exist
# finished 234 / 960 : 24.38%
# tilt corrected file already exist
# folder already exist
# finished 235 / 960 : 24.48%
# tilt corrected file already exist
# folder already exist
# finished 236 / 960 : 24.58%
# tilt corrected file already exist
# folder already exist
# finished 237 / 960 : 24.69%
# tilt corrected file already exist
# folder already exist
# finished 238 / 960 : 24.79%
# tilt corrected file already exist
# folder already exist
# finished 239 / 960 : 24.90%
# tilt corrected file already exist
# folder already exist
# finished 240 / 960 : 25.00%
# tilt corrected file already exist
# folder already exist
# finished 241 / 960 : 25.10%
# tilt corrected file already exist
# folder already exist
# finished 242 / 960 : 25.21%
# tilt corrected file already exist
# folder already exist
# finished 243 / 960 : 25.31%
# tilt corrected file already exist
# folder already exist
# finished 244 / 960 : 25.42%
# tilt corrected file already exist
# folder already exist
# finished 245 / 960 : 25.52%
# tilt corrected file already exist
# folder already exist
# finished 246 / 960 : 25.62%
# tilt corrected file already exist
# folder already exist
# finished 247 / 960 : 25.73%
# tilt corrected file already exist
# folder already exist
# finished 248 / 960 : 25.83%
# tilt corrected file already exist
# folder already exist
# finished 249 / 960 : 25.94%
# tilt corrected file already exist
# folder already exist
# finished 250 / 960 : 26.04%
# tilt corrected file already exist
# folder already exist
# finished 251 / 960 : 26.15%
# tilt corrected file already exist
# folder already exist
# finished 252 / 960 : 26.25%
# tilt corrected file already exist
# folder already exist
# finished 253 / 960 : 26.35%
# tilt corrected file already exist
# folder already exist
# finished 254 / 960 : 26.46%
# tilt corrected file already exist
# folder already exist
# finished 255 / 960 : 26.56%
# tilt corrected file already exist
# folder already exist
# finished 256 / 960 : 26.67%
# tilt corrected file already exist
# folder already exist
# finished 257 / 960 : 26.77%
# tilt corrected file already exist
# folder already exist
# finished 258 / 960 : 26.88%
# tilt corrected file already exist
# folder already exist
# finished 259 / 960 : 26.98%
# tilt corrected file already exist
# folder already exist
# finished 260 / 960 : 27.08%
# tilt corrected file already exist
# folder already exist
# finished 261 / 960 : 27.19%
# tilt corrected file already exist
# folder already exist
# finished 262 / 960 : 27.29%
# tilt corrected file already exist
# folder already exist
# finished 263 / 960 : 27.40%
# tilt corrected file already exist
# folder already exist
# finished 264 / 960 : 27.50%
# tilt corrected file already exist
# folder already exist
# finished 265 / 960 : 27.60%
# tilt corrected file already exist
# folder already exist
# finished 266 / 960 : 27.71%
# tilt corrected file already exist
# folder already exist
# finished 267 / 960 : 27.81%
# tilt corrected file already exist
# folder already exist
# finished 268 / 960 : 27.92%
# tilt corrected file already exist
# folder already exist
# finished 269 / 960 : 28.02%
# tilt corrected file already exist
# folder already exist
# finished 270 / 960 : 28.12%
# tilt corrected file already exist
# folder already exist
# finished 271 / 960 : 28.23%
# tilt corrected file already exist
# folder already exist
# finished 272 / 960 : 28.33%
# tilt corrected file already exist
# folder already exist
# finished 273 / 960 : 28.44%
# tilt corrected file already exist
# folder already exist
# finished 274 / 960 : 28.54%
# tilt corrected file already exist
# folder already exist
# finished 275 / 960 : 28.65%
# tilt corrected file already exist
# folder already exist
# finished 276 / 960 : 28.75%
# tilt corrected file already exist
# folder already exist
# finished 277 / 960 : 28.85%
# tilt corrected file already exist
# folder already exist
# finished 278 / 960 : 28.96%
# tilt corrected file already exist
# folder already exist
# finished 279 / 960 : 29.06%
# tilt corrected file already exist
# folder already exist
# finished 280 / 960 : 29.17%
# tilt corrected file already exist
# folder already exist
# finished 281 / 960 : 29.27%
# tilt corrected file already exist
# folder already exist
# finished 282 / 960 : 29.38%
# tilt corrected file already exist
# folder already exist
# finished 283 / 960 : 29.48%
# tilt corrected file already exist
# folder already exist
# finished 284 / 960 : 29.58%
# tilt corrected file already exist
# folder already exist
# finished 285 / 960 : 29.69%
# tilt corrected file already exist
# folder already exist
# finished 286 / 960 : 29.79%
# tilt corrected file already exist
# folder already exist
# finished 287 / 960 : 29.90%
# tilt corrected file already exist
# folder already exist
# finished 288 / 960 : 30.00%
# tilt corrected file already exist
# folder already exist
# finished 289 / 960 : 30.10%
# tilt corrected file already exist
# folder already exist
# finished 290 / 960 : 30.21%
# tilt corrected file already exist
# folder already exist
# finished 291 / 960 : 30.31%
# tilt corrected file already exist
# folder already exist
# finished 292 / 960 : 30.42%
# tilt corrected file already exist
# folder already exist
# finished 293 / 960 : 30.52%
# tilt corrected file already exist
# folder already exist
# finished 294 / 960 : 30.62%
# tilt corrected file already exist
# folder already exist
# finished 295 / 960 : 30.73%
# tilt corrected file already exist
# folder already exist
# finished 296 / 960 : 30.83%
# tilt corrected file already exist
# folder already exist
# finished 297 / 960 : 30.94%
# tilt corrected file already exist
# folder already exist
# finished 298 / 960 : 31.04%
# tilt corrected file already exist
# folder already exist
# finished 299 / 960 : 31.15%
# tilt corrected file already exist
# folder already exist
# finished 300 / 960 : 31.25%
# tilt corrected file already exist
# folder already exist
# finished 301 / 960 : 31.35%
# tilt corrected file already exist
# folder already exist
# finished 302 / 960 : 31.46%
# tilt corrected file already exist
# folder already exist
# finished 303 / 960 : 31.56%
# tilt corrected file already exist
# folder already exist
# finished 304 / 960 : 31.67%
# tilt corrected file already exist
# folder already exist
# finished 305 / 960 : 31.77%
# tilt corrected file already exist
# folder already exist
# finished 306 / 960 : 31.88%
# tilt corrected file already exist
# folder already exist
# finished 307 / 960 : 31.98%
# tilt corrected file already exist
# folder already exist
# finished 308 / 960 : 32.08%
# tilt corrected file already exist
# folder already exist
# finished 309 / 960 : 32.19%
# tilt corrected file already exist
# folder already exist
# finished 310 / 960 : 32.29%
# tilt corrected file already exist
# folder already exist
# finished 311 / 960 : 32.40%
# tilt corrected file already exist
# folder already exist
# finished 312 / 960 : 32.50%
# tilt corrected file already exist
# folder already exist
# finished 313 / 960 : 32.60%
# tilt corrected file already exist
# folder already exist
# finished 314 / 960 : 32.71%
# tilt corrected file already exist
# folder already exist
# finished 315 / 960 : 32.81%
# tilt corrected file already exist
# folder already exist
# finished 316 / 960 : 32.92%
# tilt corrected file already exist
# folder already exist
# finished 317 / 960 : 33.02%
# tilt corrected file already exist
# folder already exist
# finished 318 / 960 : 33.12%
# tilt corrected file already exist
# folder already exist
# finished 319 / 960 : 33.23%
# tilt corrected file already exist
# folder already exist
# finished 320 / 960 : 33.33%
# tilt corrected file already exist
# folder already exist
# finished 321 / 960 : 33.44%
# tilt corrected file already exist
# folder already exist
# finished 322 / 960 : 33.54%
# tilt corrected file already exist
# folder already exist
# finished 323 / 960 : 33.65%
# tilt corrected file already exist
# folder already exist
# finished 324 / 960 : 33.75%
# tilt corrected file already exist
# folder already exist
# finished 325 / 960 : 33.85%
# tilt corrected file already exist
# folder already exist
# finished 326 / 960 : 33.96%
# tilt corrected file already exist
# folder already exist
# finished 327 / 960 : 34.06%
# tilt corrected file already exist
# folder already exist
# finished 328 / 960 : 34.17%
# tilt corrected file already exist
# folder already exist
# finished 329 / 960 : 34.27%
# tilt corrected file already exist
# folder already exist
# finished 330 / 960 : 34.38%
# tilt corrected file already exist
# folder already exist
# finished 331 / 960 : 34.48%
# tilt corrected file already exist
# folder already exist
# finished 332 / 960 : 34.58%
# tilt corrected file already exist
# folder already exist
# finished 333 / 960 : 34.69%
# tilt corrected file already exist
# folder already exist
# finished 334 / 960 : 34.79%
# tilt corrected file already exist
# folder already exist
# finished 335 / 960 : 34.90%
# tilt corrected file already exist
# folder already exist
# finished 336 / 960 : 35.00%
# tilt corrected file already exist
# folder already exist
# finished 337 / 960 : 35.10%
# tilt corrected file already exist
# folder already exist
# finished 338 / 960 : 35.21%
# tilt corrected file already exist
# folder already exist
# finished 339 / 960 : 35.31%
# tilt corrected file already exist
# folder already exist
# finished 340 / 960 : 35.42%
# tilt corrected file already exist
# folder already exist
# finished 341 / 960 : 35.52%
# tilt corrected file already exist
# folder already exist
# finished 342 / 960 : 35.62%
# tilt corrected file already exist
# folder already exist
# finished 343 / 960 : 35.73%
# tilt corrected file already exist
# folder already exist
# finished 344 / 960 : 35.83%
# tilt corrected file already exist
# folder already exist
# finished 345 / 960 : 35.94%
# tilt corrected file already exist
# folder already exist
# finished 346 / 960 : 36.04%
# tilt corrected file already exist
# folder already exist
# finished 347 / 960 : 36.15%
# tilt corrected file already exist
# folder already exist
# finished 348 / 960 : 36.25%
# tilt corrected file already exist
# folder already exist
# finished 349 / 960 : 36.35%
# tilt corrected file already exist
# folder already exist
# finished 350 / 960 : 36.46%
# tilt corrected file already exist
# folder already exist
# finished 351 / 960 : 36.56%
# tilt corrected file already exist
# folder already exist
# finished 352 / 960 : 36.67%
# tilt corrected file already exist
# folder already exist
# finished 353 / 960 : 36.77%
# tilt corrected file already exist
# folder already exist
# finished 354 / 960 : 36.88%
# tilt corrected file already exist
# folder already exist
# finished 355 / 960 : 36.98%
# tilt corrected file already exist
# folder already exist
# finished 356 / 960 : 37.08%
# tilt corrected file already exist
# folder already exist
# finished 357 / 960 : 37.19%
# tilt corrected file already exist
# folder already exist
# finished 358 / 960 : 37.29%
# tilt corrected file already exist
# folder already exist
# finished 359 / 960 : 37.40%
# tilt corrected file already exist
# folder already exist
# finished 360 / 960 : 37.50%
# tilt corrected file already exist
# folder already exist
# finished 361 / 960 : 37.60%
# tilt corrected file already exist
# folder already exist
# finished 362 / 960 : 37.71%
# tilt corrected file already exist
# folder already exist
# finished 363 / 960 : 37.81%
# tilt corrected file already exist
# folder already exist
# finished 364 / 960 : 37.92%
# tilt corrected file already exist
# folder already exist
# finished 365 / 960 : 38.02%
# tilt corrected file already exist
# folder already exist
# finished 366 / 960 : 38.12%
# tilt corrected file already exist
# folder already exist
# finished 367 / 960 : 38.23%
# tilt corrected file already exist
# folder already exist
# finished 368 / 960 : 38.33%
# tilt corrected file already exist
# folder already exist
# finished 369 / 960 : 38.44%
# tilt corrected file already exist
# folder already exist
# finished 370 / 960 : 38.54%
# tilt corrected file already exist
# folder already exist
# finished 371 / 960 : 38.65%
# tilt corrected file already exist
# folder already exist
# finished 372 / 960 : 38.75%
# tilt corrected file already exist
# folder already exist
# finished 373 / 960 : 38.85%
# tilt corrected file already exist
# folder already exist
# finished 374 / 960 : 38.96%
# tilt corrected file already exist
# folder already exist
# finished 375 / 960 : 39.06%
# tilt corrected file already exist
# folder already exist
# finished 376 / 960 : 39.17%
# tilt corrected file already exist
# folder already exist
# finished 377 / 960 : 39.27%
# tilt corrected file already exist
# folder already exist
# finished 378 / 960 : 39.38%
# tilt corrected file already exist
# folder already exist
# finished 379 / 960 : 39.48%
# tilt corrected file already exist
# folder already exist
# finished 380 / 960 : 39.58%
# tilt corrected file already exist
# folder already exist
# finished 381 / 960 : 39.69%
# tilt corrected file already exist
# folder already exist
# finished 382 / 960 : 39.79%
# tilt corrected file already exist
# folder already exist
# finished 383 / 960 : 39.90%
# tilt corrected file already exist
# folder already exist
# finished 384 / 960 : 40.00%
# tilt corrected file already exist
# folder already exist
# finished 385 / 960 : 40.10%
# tilt corrected file already exist
# folder already exist
# finished 386 / 960 : 40.21%
# tilt corrected file already exist
# folder already exist
# finished 387 / 960 : 40.31%
# tilt corrected file already exist
# folder already exist
# finished 388 / 960 : 40.42%
# tilt corrected file already exist
# folder already exist
# finished 389 / 960 : 40.52%
# tilt corrected file already exist
# folder already exist
# finished 390 / 960 : 40.62%
# tilt corrected file already exist
# folder already exist
# finished 391 / 960 : 40.73%
# tilt corrected file already exist
# folder already exist
# finished 392 / 960 : 40.83%
# tilt corrected file already exist
# folder already exist
# finished 393 / 960 : 40.94%
# tilt corrected file already exist
# folder already exist
# finished 394 / 960 : 41.04%
# tilt corrected file already exist
# folder already exist
# finished 395 / 960 : 41.15%
# tilt corrected file already exist
# folder already exist
# finished 396 / 960 : 41.25%
# tilt corrected file already exist
# folder already exist
# finished 397 / 960 : 41.35%
# tilt corrected file already exist
# folder already exist
# finished 398 / 960 : 41.46%
# tilt corrected file already exist
# folder already exist
# finished 399 / 960 : 41.56%
# tilt corrected file already exist
# folder already exist
# finished 400 / 960 : 41.67%
# tilt corrected file already exist
# folder already exist
# finished 401 / 960 : 41.77%
# tilt corrected file already exist
# folder already exist
# finished 402 / 960 : 41.88%
# tilt corrected file already exist
# folder already exist
# finished 403 / 960 : 41.98%
# tilt corrected file already exist
# folder already exist
# finished 404 / 960 : 42.08%
# tilt corrected file already exist
# folder already exist
# finished 405 / 960 : 42.19%
# tilt corrected file already exist
# folder already exist
# finished 406 / 960 : 42.29%
# tilt corrected file already exist
# folder already exist
# finished 407 / 960 : 42.40%
# tilt corrected file already exist
# folder already exist
# finished 408 / 960 : 42.50%
# tilt corrected file already exist
# folder already exist
# finished 409 / 960 : 42.60%
# tilt corrected file already exist
# folder already exist
# finished 410 / 960 : 42.71%
# tilt corrected file already exist
# folder already exist
# finished 411 / 960 : 42.81%
# tilt corrected file already exist
# folder already exist
# finished 412 / 960 : 42.92%
# tilt corrected file already exist
# folder already exist
# finished 413 / 960 : 43.02%
# tilt corrected file already exist
# folder already exist
# finished 414 / 960 : 43.12%
# tilt corrected file already exist
# folder already exist
# finished 415 / 960 : 43.23%
# tilt corrected file already exist
# folder already exist
# finished 416 / 960 : 43.33%
# tilt corrected file already exist
# folder already exist
# finished 417 / 960 : 43.44%
# tilt corrected file already exist
# folder already exist
# finished 418 / 960 : 43.54%
# tilt corrected file already exist
# folder already exist
# finished 419 / 960 : 43.65%
# tilt corrected file already exist
# folder already exist
# finished 420 / 960 : 43.75%
# tilt corrected file already exist
# folder already exist
# finished 421 / 960 : 43.85%
# tilt corrected file already exist
# folder already exist
# finished 422 / 960 : 43.96%
# tilt corrected file already exist
# folder already exist
# finished 423 / 960 : 44.06%
# tilt corrected file already exist
# folder already exist
# finished 424 / 960 : 44.17%
# tilt corrected file already exist
# folder already exist
# finished 425 / 960 : 44.27%
# tilt corrected file already exist
# folder already exist
# finished 426 / 960 : 44.38%
# tilt corrected file already exist
# folder already exist
# finished 427 / 960 : 44.48%
# tilt corrected file already exist
# folder already exist
# finished 428 / 960 : 44.58%
# tilt corrected file already exist
# folder already exist
# finished 429 / 960 : 44.69%
# tilt corrected file already exist
# folder already exist
# finished 430 / 960 : 44.79%
# tilt corrected file already exist
# folder already exist
# finished 431 / 960 : 44.90%
# tilt corrected file already exist
# folder already exist
# finished 432 / 960 : 45.00%
# tilt corrected file already exist
# folder already exist
# finished 433 / 960 : 45.10%
# tilt corrected file already exist
# folder already exist
# finished 434 / 960 : 45.21%
# tilt corrected file already exist
# folder already exist
# finished 435 / 960 : 45.31%
# tilt corrected file already exist
# folder already exist
# finished 436 / 960 : 45.42%
# tilt corrected file already exist
# folder already exist
# finished 437 / 960 : 45.52%
# tilt corrected file already exist
# folder already exist
# finished 438 / 960 : 45.62%
# tilt corrected file already exist
# folder already exist
# finished 439 / 960 : 45.73%
# tilt corrected file already exist
# folder already exist
# finished 440 / 960 : 45.83%
# tilt corrected file already exist
# folder already exist
# finished 441 / 960 : 45.94%
# tilt corrected file already exist
# folder already exist
# finished 442 / 960 : 46.04%
# tilt corrected file already exist
# folder already exist
# finished 443 / 960 : 46.15%
# tilt corrected file already exist
# folder already exist
# finished 444 / 960 : 46.25%
# tilt corrected file already exist
# folder already exist
# finished 445 / 960 : 46.35%
# tilt corrected file already exist
# folder already exist
# finished 446 / 960 : 46.46%
# tilt corrected file already exist
# folder already exist
# finished 447 / 960 : 46.56%
# tilt corrected file already exist
# folder already exist
# finished 448 / 960 : 46.67%
# tilt corrected file already exist
# folder already exist
# finished 449 / 960 : 46.77%
# tilt corrected file already exist
# folder already exist
# finished 450 / 960 : 46.88%
# tilt corrected file already exist
# folder already exist
# finished 451 / 960 : 46.98%
# tilt corrected file already exist
# folder already exist
# finished 452 / 960 : 47.08%
# tilt corrected file already exist
# folder already exist
# finished 453 / 960 : 47.19%
# tilt corrected file already exist
# folder already exist
# finished 454 / 960 : 47.29%
# tilt corrected file already exist
# folder already exist
# finished 455 / 960 : 47.40%
# tilt corrected file already exist
# folder already exist
# finished 456 / 960 : 47.50%
# tilt corrected file already exist
# folder already exist
# finished 457 / 960 : 47.60%
# tilt corrected file already exist
# folder already exist
# finished 458 / 960 : 47.71%
# tilt corrected file already exist
# folder already exist
# finished 459 / 960 : 47.81%
# tilt corrected file already exist
# folder already exist
# finished 460 / 960 : 47.92%
# tilt corrected file already exist
# folder already exist
# finished 461 / 960 : 48.02%
# tilt corrected file already exist
# folder already exist
# finished 462 / 960 : 48.12%
# tilt corrected file already exist
# folder already exist
# finished 463 / 960 : 48.23%
# tilt corrected file already exist
# folder already exist
# finished 464 / 960 : 48.33%
# tilt corrected file already exist
# folder already exist
# finished 465 / 960 : 48.44%
# tilt corrected file already exist
# folder already exist
# finished 466 / 960 : 48.54%
# tilt corrected file already exist
# folder already exist
# finished 467 / 960 : 48.65%
# tilt corrected file already exist
# folder already exist
# finished 468 / 960 : 48.75%
# tilt corrected file already exist
# folder already exist
# finished 469 / 960 : 48.85%
# tilt corrected file already exist
# folder already exist
# finished 470 / 960 : 48.96%
# tilt corrected file already exist
# folder already exist
# finished 471 / 960 : 49.06%
# tilt corrected file already exist
# folder already exist
# finished 472 / 960 : 49.17%
# tilt corrected file already exist
# folder already exist
# finished 473 / 960 : 49.27%
# tilt corrected file already exist
# folder already exist
# finished 474 / 960 : 49.38%
# tilt corrected file already exist
# folder already exist
# finished 475 / 960 : 49.48%
# tilt corrected file already exist
# folder already exist
# finished 476 / 960 : 49.58%
# tilt corrected file already exist
# folder already exist
# finished 477 / 960 : 49.69%
# tilt corrected file already exist
# folder already exist
# finished 478 / 960 : 49.79%
# tilt corrected file already exist
# folder already exist
# finished 479 / 960 : 49.90%
# tilt corrected file already exist
# folder already exist
# finished 480 / 960 : 50.00%
# tilt corrected file already exist
# folder already exist
# finished 481 / 960 : 50.10%
# tilt corrected file already exist
# folder already exist
# finished 482 / 960 : 50.21%
# tilt corrected file already exist
# folder already exist
# finished 483 / 960 : 50.31%
# tilt corrected file already exist
# folder already exist
# finished 484 / 960 : 50.42%
# tilt corrected file already exist
# folder already exist
# finished 485 / 960 : 50.52%
# tilt corrected file already exist
# folder already exist
# finished 486 / 960 : 50.62%
# tilt corrected file already exist
# folder already exist
# finished 487 / 960 : 50.73%
# tilt corrected file already exist
# folder already exist
# finished 488 / 960 : 50.83%
# tilt corrected file already exist
# folder already exist
# finished 489 / 960 : 50.94%
# tilt corrected file already exist
# folder already exist
# finished 490 / 960 : 51.04%
# tilt corrected file already exist
# folder already exist
# finished 491 / 960 : 51.15%
# tilt corrected file already exist
# folder already exist
# finished 492 / 960 : 51.25%
# tilt corrected file already exist
# folder already exist
# finished 493 / 960 : 51.35%
# tilt corrected file already exist
# folder already exist
# finished 494 / 960 : 51.46%
# tilt corrected file already exist
# folder already exist
# finished 495 / 960 : 51.56%
# tilt corrected file already exist
# folder already exist
# finished 496 / 960 : 51.67%
# tilt corrected file already exist
# folder already exist
# finished 497 / 960 : 51.77%
# tilt corrected file already exist
# folder already exist
# finished 498 / 960 : 51.88%
# tilt corrected file already exist
# folder already exist
# finished 499 / 960 : 51.98%
# tilt corrected file already exist
# folder already exist
# finished 500 / 960 : 52.08%
# tilt corrected file already exist
# folder already exist
# finished 501 / 960 : 52.19%
# tilt corrected file already exist
# folder already exist
# finished 502 / 960 : 52.29%
# tilt corrected file already exist
# folder already exist
# finished 503 / 960 : 52.40%
# tilt corrected file already exist
# folder already exist
# finished 504 / 960 : 52.50%
# tilt corrected file already exist
# folder already exist
# finished 505 / 960 : 52.60%
# tilt corrected file already exist
# folder already exist
# finished 506 / 960 : 52.71%
# tilt corrected file already exist
# folder already exist
# finished 507 / 960 : 52.81%
# tilt corrected file already exist
# folder already exist
# finished 508 / 960 : 52.92%
# tilt corrected file already exist
# folder already exist
# finished 509 / 960 : 53.02%
# tilt corrected file already exist
# folder already exist
# finished 510 / 960 : 53.12%
# tilt corrected file already exist
# folder already exist
# finished 511 / 960 : 53.23%
# tilt corrected file already exist
# folder already exist
# finished 512 / 960 : 53.33%
# tilt corrected file already exist
# folder already exist
# finished 513 / 960 : 53.44%
# tilt corrected file already exist
# folder already exist
# finished 514 / 960 : 53.54%
# tilt corrected file already exist
# folder already exist
# finished 515 / 960 : 53.65%
# tilt corrected file already exist
# folder already exist
# finished 516 / 960 : 53.75%
# tilt corrected file already exist
# folder already exist
# finished 517 / 960 : 53.85%
# tilt corrected file already exist
# folder already exist
# finished 518 / 960 : 53.96%
# tilt corrected file already exist
# folder already exist
# finished 519 / 960 : 54.06%
# tilt corrected file already exist
# folder already exist
# finished 520 / 960 : 54.17%
# tilt corrected file already exist
# folder already exist
# finished 521 / 960 : 54.27%
# tilt corrected file already exist
# folder already exist
# finished 522 / 960 : 54.38%
# tilt corrected file already exist
# folder already exist
# finished 523 / 960 : 54.48%
# tilt corrected file already exist
# folder already exist
# finished 524 / 960 : 54.58%
# tilt corrected file already exist
# folder already exist
# finished 525 / 960 : 54.69%
# tilt corrected file already exist
# folder already exist
# finished 526 / 960 : 54.79%
# tilt corrected file already exist
# folder already exist
# finished 527 / 960 : 54.90%
# tilt corrected file already exist
# folder already exist
# finished 528 / 960 : 55.00%
# tilt corrected file already exist
# folder already exist
# finished 529 / 960 : 55.10%
# tilt corrected file already exist
# folder already exist
# finished 530 / 960 : 55.21%
# tilt corrected file already exist
# folder already exist
# finished 531 / 960 : 55.31%
# tilt corrected file already exist
# folder already exist
# finished 532 / 960 : 55.42%
# tilt corrected file already exist
# folder already exist
# finished 533 / 960 : 55.52%
# tilt corrected file already exist
# folder already exist
# finished 534 / 960 : 55.62%
# tilt corrected file already exist
# folder already exist
# finished 535 / 960 : 55.73%
# tilt corrected file already exist
# folder already exist
# finished 536 / 960 : 55.83%
# tilt corrected file already exist
# folder already exist
# finished 537 / 960 : 55.94%
# tilt corrected file already exist
# folder already exist
# finished 538 / 960 : 56.04%
# tilt corrected file already exist
# folder already exist
# finished 539 / 960 : 56.15%
# tilt corrected file already exist
# folder already exist
# finished 540 / 960 : 56.25%
# tilt corrected file already exist
# folder already exist
# finished 541 / 960 : 56.35%
# tilt corrected file already exist
# folder already exist
# finished 542 / 960 : 56.46%
# tilt corrected file already exist
# folder already exist
# finished 543 / 960 : 56.56%
# tilt corrected file already exist
# folder already exist
# finished 544 / 960 : 56.67%
# tilt corrected file already exist
# folder already exist
# finished 545 / 960 : 56.77%
# tilt corrected file already exist
# folder already exist
# finished 546 / 960 : 56.88%
# tilt corrected file already exist
# folder already exist
# finished 547 / 960 : 56.98%
# tilt corrected file already exist
# folder already exist
# finished 548 / 960 : 57.08%
# tilt corrected file already exist
# folder already exist
# finished 549 / 960 : 57.19%
# tilt corrected file already exist
# folder already exist
# finished 550 / 960 : 57.29%
# tilt corrected file already exist
# folder already exist
# finished 551 / 960 : 57.40%
# tilt corrected file already exist
# folder already exist
# finished 552 / 960 : 57.50%
# tilt corrected file already exist
# folder already exist
# finished 553 / 960 : 57.60%
# tilt corrected file already exist
# folder already exist
# finished 554 / 960 : 57.71%
# tilt corrected file already exist
# folder already exist
# finished 555 / 960 : 57.81%
# tilt corrected file already exist
# folder already exist
# finished 556 / 960 : 57.92%
# tilt corrected file already exist
# folder already exist
# finished 557 / 960 : 58.02%
# tilt corrected file already exist
# folder already exist
# finished 558 / 960 : 58.12%
# tilt corrected file already exist
# folder already exist
# finished 559 / 960 : 58.23%
# tilt corrected file already exist
# folder already exist
# finished 560 / 960 : 58.33%
# tilt corrected file already exist
# folder already exist
# finished 561 / 960 : 58.44%
# tilt corrected file already exist
# folder already exist
# finished 562 / 960 : 58.54%
# tilt corrected file already exist
# folder already exist
# finished 563 / 960 : 58.65%
# tilt corrected file already exist
# folder already exist
# finished 564 / 960 : 58.75%
# tilt corrected file already exist
# folder already exist
# finished 565 / 960 : 58.85%
# tilt corrected file already exist
# folder already exist
# finished 566 / 960 : 58.96%
# tilt corrected file already exist
# folder already exist
# finished 567 / 960 : 59.06%
# tilt corrected file already exist
# folder already exist
# finished 568 / 960 : 59.17%
# tilt corrected file already exist
# folder already exist
# finished 569 / 960 : 59.27%
# tilt corrected file already exist
# folder already exist
# finished 570 / 960 : 59.38%
# tilt corrected file already exist
# folder already exist
# finished 571 / 960 : 59.48%
# tilt corrected file already exist
# folder already exist
# finished 572 / 960 : 59.58%
# tilt corrected file already exist
# folder already exist
# finished 573 / 960 : 59.69%
# tilt corrected file already exist
# folder already exist
# finished 574 / 960 : 59.79%
# tilt corrected file already exist
# folder already exist
# finished 575 / 960 : 59.90%
# tilt corrected file already exist
# folder already exist
# finished 576 / 960 : 60.00%
# tilt corrected file already exist
# folder already exist
# finished 577 / 960 : 60.10%
# tilt corrected file already exist
# folder already exist
# finished 578 / 960 : 60.21%
# tilt corrected file already exist
# folder already exist
# finished 579 / 960 : 60.31%
# tilt corrected file already exist
# folder already exist
# finished 580 / 960 : 60.42%
# tilt corrected file already exist
# folder already exist
# ...
# folder already exist
# finished 768 / 960 : 80.00%
# tilt corrected file already exist
# folder already exist
# finished 769 / 960 : 80.10%
# tilt corrected file already exist
# folder already exist
# finished 770 / 960 : 80.21%
# tilt corrected file already exist
# folder already exist
# finished 771 / 960 : 80.31%
# tilt corrected file already exist
# folder already exist
# finished 772 / 960 : 80.42%
# tilt corrected file already exist
# folder already exist
# finished 773 / 960 : 80.52%
# tilt corrected file already exist
# folder already exist
# finished 774 / 960 : 80.62%
# tilt corrected file already exist
# folder already exist
# finished 775 / 960 : 80.73%
# tilt corrected file already exist
# folder already exist
# finished 776 / 960 : 80.83%
# tilt corrected file already exist
# folder already exist
# finished 777 / 960 : 80.94%
# tilt corrected file already exist
# folder already exist
# finished 778 / 960 : 81.04%
# tilt corrected file already exist
# folder already exist
# finished 779 / 960 : 81.15%
# tilt corrected file already exist
# folder already exist
# finished 780 / 960 : 81.25%
# tilt corrected file already exist
# folder already exist
# finished 781 / 960 : 81.35%
# tilt corrected file already exist
# folder already exist
# finished 782 / 960 : 81.46%
# tilt corrected file already exist
# folder already exist
# finished 783 / 960 : 81.56%
# tilt corrected file already exist
# folder already exist
# finished 784 / 960 : 81.67%
# tilt corrected file already exist
# folder already exist
# finished 785 / 960 : 81.77%
# tilt corrected file already exist
# folder already exist
# finished 786 / 960 : 81.88%
# tilt corrected file already exist
# folder already exist
# finished 787 / 960 : 81.98%
# tilt corrected file already exist
# folder already exist
# finished 788 / 960 : 82.08%
# tilt corrected file already exist
# folder already exist
# finished 789 / 960 : 82.19%
# tilt corrected file already exist
# folder already exist
# finished 790 / 960 : 82.29%
# tilt corrected file already exist
# folder already exist
# finished 791 / 960 : 82.40%
# tilt corrected file already exist
# folder already exist
# finished 792 / 960 : 82.50%
# tilt corrected file already exist
# folder already exist
# finished 793 / 960 : 82.60%
# tilt corrected file already exist
# folder already exist
# finished 794 / 960 : 82.71%
# tilt corrected file already exist
# folder already exist
# finished 795 / 960 : 82.81%
# tilt corrected file already exist
# folder already exist
# finished 796 / 960 : 82.92%
# tilt corrected file already exist
# folder already exist
# finished 797 / 960 : 83.02%
# tilt corrected file already exist
# folder already exist
# finished 798 / 960 : 83.12%
# tilt corrected file already exist
# folder already exist
# finished 799 / 960 : 83.23%
# tilt corrected file already exist
# folder already exist
# finished 800 / 960 : 83.33%
# tilt corrected file already exist
# folder already exist
# finished 801 / 960 : 83.44%
# tilt corrected file already exist
# folder already exist
# finished 802 / 960 : 83.54%
# tilt corrected file already exist
# folder already exist
# finished 803 / 960 : 83.65%
# tilt corrected file already exist
# folder already exist
# finished 804 / 960 : 83.75%
# tilt corrected file already exist
# folder already exist
# finished 805 / 960 : 83.85%
# tilt corrected file already exist
# folder already exist
# finished 806 / 960 : 83.96%
# tilt corrected file already exist
# folder already exist
# finished 807 / 960 : 84.06%
# tilt corrected file already exist
# folder already exist
# finished 808 / 960 : 84.17%
# tilt corrected file already exist
# folder already exist
# finished 809 / 960 : 84.27%
# tilt corrected file already exist
# folder already exist
# finished 810 / 960 : 84.38%
# tilt corrected file already exist
# folder already exist
# finished 811 / 960 : 84.48%
# tilt corrected file already exist
# folder already exist
# finished 812 / 960 : 84.58%
# tilt corrected file already exist
# folder already exist
# finished 813 / 960 : 84.69%
# tilt corrected file already exist
# folder already exist
# finished 814 / 960 : 84.79%
# tilt corrected file already exist
# folder already exist
# finished 815 / 960 : 84.90%
# tilt corrected file already exist
# folder already exist
# finished 816 / 960 : 85.00%
# tilt corrected file already exist
# folder already exist
# finished 817 / 960 : 85.10%
# tilt corrected file already exist
# folder already exist
# finished 818 / 960 : 85.21%
# tilt corrected file already exist
# folder already exist
# finished 819 / 960 : 85.31%
# tilt corrected file already exist
# folder already exist
# finished 820 / 960 : 85.42%
# tilt corrected file already exist
# folder already exist
# finished 821 / 960 : 85.52%
# tilt corrected file already exist
# folder already exist
# finished 822 / 960 : 85.62%
# tilt corrected file already exist
# folder already exist
# finished 823 / 960 : 85.73%
# tilt corrected file already exist
# folder already exist
# finished 824 / 960 : 85.83%
# tilt corrected file already exist
# folder already exist
# finished 825 / 960 : 85.94%
# tilt corrected file already exist
# folder already exist
# finished 826 / 960 : 86.04%
# tilt corrected file already exist
# folder already exist
# finished 827 / 960 : 86.15%
# tilt corrected file already exist
# folder already exist
# finished 828 / 960 : 86.25%
# tilt corrected file already exist
# folder already exist
# finished 829 / 960 : 86.35%
# tilt corrected file already exist
# folder already exist
# finished 830 / 960 : 86.46%
# tilt corrected file already exist
# folder already exist
# finished 831 / 960 : 86.56%
# tilt corrected file already exist
# folder already exist
# finished 832 / 960 : 86.67%
# tilt corrected file already exist
# folder already exist
# finished 833 / 960 : 86.77%
# tilt corrected file already exist
# folder already exist
# finished 834 / 960 : 86.88%
# tilt corrected file already exist
# folder already exist
# finished 835 / 960 : 86.98%
# tilt corrected file already exist
# folder already exist
# finished 836 / 960 : 87.08%
# tilt corrected file already exist
# folder already exist
# finished 837 / 960 : 87.19%
# tilt corrected file already exist
# folder already exist
# finished 838 / 960 : 87.29%
# tilt corrected file already exist
# folder already exist
# finished 839 / 960 : 87.40%
# tilt corrected file already exist
# folder already exist
# finished 840 / 960 : 87.50%
# tilt corrected file already exist
# folder already exist
# finished 841 / 960 : 87.60%
# tilt corrected file already exist
# folder already exist
# finished 842 / 960 : 87.71%
# tilt corrected file already exist
# folder already exist
# finished 843 / 960 : 87.81%
# tilt corrected file already exist
# folder already exist
# finished 844 / 960 : 87.92%
# tilt corrected file already exist
# folder already exist
# finished 845 / 960 : 88.02%
# tilt corrected file already exist
# folder already exist
# finished 846 / 960 : 88.12%
# tilt corrected file already exist
# folder already exist
# finished 847 / 960 : 88.23%
# tilt corrected file already exist
# folder already exist
# finished 848 / 960 : 88.33%
# tilt corrected file already exist
# folder already exist
# finished 849 / 960 : 88.44%
# tilt corrected file already exist
# folder already exist
# finished 850 / 960 : 88.54%
# tilt corrected file already exist
# folder already exist
# finished 851 / 960 : 88.65%
# tilt corrected file already exist
# folder already exist
# finished 852 / 960 : 88.75%
# tilt corrected file already exist
# folder already exist
# finished 853 / 960 : 88.85%
# tilt corrected file already exist
# folder already exist
# finished 854 / 960 : 88.96%
# tilt corrected file already exist
# folder already exist
# finished 855 / 960 : 89.06%
# tilt corrected file already exist
# folder already exist
# finished 856 / 960 : 89.17%
# tilt corrected file already exist
# folder already exist
# finished 857 / 960 : 89.27%
# tilt corrected file already exist
# folder already exist
# finished 858 / 960 : 89.38%
# tilt corrected file already exist
# folder already exist
# finished 859 / 960 : 89.48%
# tilt corrected file already exist
# folder already exist
# finished 860 / 960 : 89.58%
# tilt corrected file already exist
# folder already exist
# finished 861 / 960 : 89.69%
# tilt corrected file already exist
# folder already exist
# finished 862 / 960 : 89.79%
# tilt corrected file already exist
# folder already exist
# finished 863 / 960 : 89.90%
# tilt corrected file already exist
# folder already exist
# finished 864 / 960 : 90.00%
# tilt corrected file already exist
# folder already exist
# finished 865 / 960 : 90.10%
# tilt corrected file already exist
# folder already exist
# finished 866 / 960 : 90.21%
# tilt corrected file already exist
# folder already exist
# finished 867 / 960 : 90.31%
# tilt corrected file already exist
# folder already exist
# finished 868 / 960 : 90.42%
# tilt corrected file already exist
# folder already exist
# finished 869 / 960 : 90.52%
# tilt corrected file already exist
# folder already exist
# finished 870 / 960 : 90.62%
# tilt corrected file already exist
# folder already exist
# finished 871 / 960 : 90.73%
# tilt corrected file already exist
# folder already exist
# finished 872 / 960 : 90.83%
# tilt corrected file already exist
# folder already exist
# finished 873 / 960 : 90.94%
# tilt corrected file already exist
# folder already exist
# finished 874 / 960 : 91.04%
# tilt corrected file already exist
# folder already exist
# finished 875 / 960 : 91.15%
# tilt corrected file already exist
# folder already exist
# finished 876 / 960 : 91.25%
# tilt corrected file already exist
# folder already exist
# finished 877 / 960 : 91.35%
# tilt corrected file already exist
# folder already exist
# finished 878 / 960 : 91.46%
# tilt corrected file already exist
# folder already exist
# finished 879 / 960 : 91.56%
# tilt corrected file already exist
# folder already exist
# finished 880 / 960 : 91.67%
# tilt corrected file already exist
# folder already exist
# finished 881 / 960 : 91.77%
# tilt corrected file already exist
# folder already exist
# finished 882 / 960 : 91.88%
# tilt corrected file already exist
# folder already exist
# finished 883 / 960 : 91.98%
# tilt corrected file already exist
# folder already exist
# finished 884 / 960 : 92.08%
# tilt corrected file already exist
# folder already exist
# finished 885 / 960 : 92.19%
# tilt corrected file already exist
# folder already exist
# finished 886 / 960 : 92.29%
# tilt corrected file already exist
# folder already exist
# finished 887 / 960 : 92.40%
# tilt corrected file already exist
# folder already exist
# finished 888 / 960 : 92.50%
# tilt corrected file already exist
# folder already exist
# finished 889 / 960 : 92.60%
# tilt corrected file already exist
# folder already exist
# finished 890 / 960 : 92.71%
# tilt corrected file already exist
# folder already exist
# finished 891 / 960 : 92.81%
# tilt corrected file already exist
# folder already exist
# finished 892 / 960 : 92.92%
# tilt corrected file already exist
# folder already exist
# finished 893 / 960 : 93.02%
# tilt corrected file already exist
# folder already exist
# finished 894 / 960 : 93.12%
# tilt corrected file already exist
# folder already exist
# finished 895 / 960 : 93.23%
# tilt corrected file already exist
# folder already exist
# finished 896 / 960 : 93.33%
# tilt corrected file already exist
# folder already exist
# finished 897 / 960 : 93.44%
# tilt corrected file already exist
# folder already exist
# finished 898 / 960 : 93.54%
# tilt corrected file already exist
# folder already exist
# finished 899 / 960 : 93.65%
# tilt corrected file already exist
# folder already exist
# finished 900 / 960 : 93.75%
# tilt corrected file already exist
# folder already exist
# finished 901 / 960 : 93.85%
# tilt corrected file already exist
# folder already exist
# finished 902 / 960 : 93.96%
# tilt corrected file already exist
# folder already exist
# finished 903 / 960 : 94.06%
# tilt corrected file already exist
# folder already exist
# finished 904 / 960 : 94.17%
# tilt corrected file already exist
# folder already exist
# finished 905 / 960 : 94.27%
# tilt corrected file already exist
# folder already exist
# finished 906 / 960 : 94.38%
# tilt corrected file already exist
# folder already exist
# finished 907 / 960 : 94.48%
# tilt corrected file already exist
# folder already exist
# finished 908 / 960 : 94.58%
# tilt corrected file already exist
# folder already exist
# finished 909 / 960 : 94.69%
# tilt corrected file already exist
# folder already exist
# finished 910 / 960 : 94.79%
# tilt corrected file already exist
# folder already exist
# finished 911 / 960 : 94.90%
# tilt corrected file already exist
# folder already exist
# finished 912 / 960 : 95.00%
# tilt corrected file already exist
# folder already exist
# finished 913 / 960 : 95.10%
# tilt corrected file already exist
# folder already exist
# finished 914 / 960 : 95.21%
# tilt corrected file already exist
# folder already exist
# finished 915 / 960 : 95.31%
# tilt corrected file already exist
# folder already exist
# finished 916 / 960 : 95.42%
# tilt corrected file already exist
# folder already exist
# finished 917 / 960 : 95.52%
# tilt corrected file already exist
# folder already exist
# finished 918 / 960 : 95.62%
# tilt corrected file already exist
# folder already exist
# finished 919 / 960 : 95.73%
# tilt corrected file already exist
# folder already exist
# finished 920 / 960 : 95.83%
# tilt corrected file already exist
# folder already exist
# finished 921 / 960 : 95.94%
# tilt corrected file already exist
# folder already exist
# finished 922 / 960 : 96.04%
# tilt corrected file already exist
# folder already exist
# finished 923 / 960 : 96.15%
# tilt corrected file already exist
# folder already exist
# finished 924 / 960 : 96.25%
# tilt corrected file already exist
# folder already exist
# finished 925 / 960 : 96.35%
# tilt corrected file already exist
# folder already exist
# finished 926 / 960 : 96.46%
# tilt corrected file already exist
# folder already exist
# finished 927 / 960 : 96.56%
# tilt corrected file already exist
# folder already exist
# finished 928 / 960 : 96.67%
# tilt corrected file already exist
# folder already exist
# finished 929 / 960 : 96.77%
# tilt corrected file already exist
# folder already exist
# finished 930 / 960 : 96.88%
# tilt corrected file already exist
# folder already exist
# finished 931 / 960 : 96.98%
# tilt corrected file already exist
# folder already exist
# finished 932 / 960 : 97.08%
# tilt corrected file already exist
# folder already exist
# finished 933 / 960 : 97.19%
# tilt corrected file already exist
# folder already exist
# finished 934 / 960 : 97.29%
# tilt corrected file already exist
# folder already exist
# finished 935 / 960 : 97.40%
# tilt corrected file already exist
# folder already exist
# finished 936 / 960 : 97.50%
# tilt corrected file already exist
# folder already exist
# finished 937 / 960 : 97.60%
# tilt corrected file already exist
# folder already exist
# finished 938 / 960 : 97.71%
# tilt corrected file already exist
# folder already exist
# finished 939 / 960 : 97.81%
# tilt corrected file already exist
# folder already exist
# finished 940 / 960 : 97.92%
# tilt corrected file already exist
# folder already exist
# finished 941 / 960 : 98.02%
# tilt corrected file already exist
# folder already exist
# finished 942 / 960 : 98.12%
# tilt corrected file already exist
# folder already exist
# finished 943 / 960 : 98.23%
# tilt corrected file already exist
# folder already exist
# finished 944 / 960 : 98.33%
# tilt corrected file already exist
# folder already exist
# finished 945 / 960 : 98.44%
# tilt corrected file already exist
# folder already exist
# finished 946 / 960 : 98.54%
# tilt corrected file already exist
# folder already exist
# finished 947 / 960 : 98.65%
# tilt corrected file already exist
# folder already exist
# finished 948 / 960 : 98.75%
# tilt corrected file already exist
# folder already exist
# finished 949 / 960 : 98.85%
# tilt corrected file already exist
# folder already exist
# finished 950 / 960 : 98.96%
# tilt corrected file already exist
# folder already exist
# finished 951 / 960 : 99.06%
# tilt corrected file already exist
# folder already exist
# finished 952 / 960 : 99.17%
# tilt corrected file already exist
# folder already exist
# finished 953 / 960 : 99.27%
# tilt corrected file already exist
# folder already exist
# finished 954 / 960 : 99.38%
# tilt corrected file already exist
# folder already exist
# finished 955 / 960 : 99.48%
# tilt corrected file already exist
# folder already exist
# finished 956 / 960 : 99.58%
# tilt corrected file already exist
# folder already exist
# finished 957 / 960 : 99.69%
# tilt corrected file already exist
# folder already exist
# finished 958 / 960 : 99.79%
# tilt corrected file already exist
# folder already exist
# finished 959 / 960 : 99.90%
# tilt corrected file already exist
# folder already exist
# finished 960 / 960 : 100.00%

# %%
# recursiveGetRidofauxxml("/Volumes/HD-PCFSU3-A/ice-wheat/data/dataForProcess/mainData")

# %%
dsmPathList
# Out:
# ['/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_1/DSM_202503010913_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_2/DSM_202503010913_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_3/DSM_202503010913_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_4/DSM_202503010913_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_5/DSM_202503010913_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_6/DSM_202503010913_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_7/DSM_202503010913_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_8/DSM_202503010913_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_9/DSM_202503010913_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_10/DSM_202503010913_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_11/DSM_202503010913_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_12/DSM_202503010913_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_13/DSM_202503010913_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_14/DSM_202503010913_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_15/DSM_202503010913_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_16/DSM_202503010913_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_17/DSM_202503010913_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_18/DSM_202503010913_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_19/DSM_202503010913_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_20/DSM_202503010913_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_21/DSM_202503010913_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_22/DSM_202503010913_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_23/DSM_202503010913_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_24/DSM_202503010913_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_25/DSM_202503010913_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_26/DSM_202503010913_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_27/DSM_202503010913_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_28/DSM_202503010913_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_29/DSM_202503010913_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_30/DSM_202503010913_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_31/DSM_202503010913_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_32/DSM_202503010913_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_33/DSM_202503010913_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_34/DSM_202503010913_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_35/DSM_202503010913_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_36/DSM_202503010913_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_37/DSM_202503010913_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_38/DSM_202503010913_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_39/DSM_202503010913_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_40/DSM_202503010913_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_41/DSM_202503010913_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_42/DSM_202503010913_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_43/DSM_202503010913_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_44/DSM_202503010913_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_45/DSM_202503010913_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_46/DSM_202503010913_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_47/DSM_202503010913_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_48/DSM_202503010913_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_49/DSM_202503010913_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_50/DSM_202503010913_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_51/DSM_202503010913_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_52/DSM_202503010913_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_53/DSM_202503010913_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_54/DSM_202503010913_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_55/DSM_202503010913_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_56/DSM_202503010913_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_57/DSM_202503010913_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_58/DSM_202503010913_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_59/DSM_202503010913_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503010913/DSM_202503010913_60/DSM_202503010913_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_1/DSM_202503111011_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_2/DSM_202503111011_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_3/DSM_202503111011_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_4/DSM_202503111011_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_5/DSM_202503111011_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_6/DSM_202503111011_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_7/DSM_202503111011_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_8/DSM_202503111011_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_9/DSM_202503111011_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_10/DSM_202503111011_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_11/DSM_202503111011_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_12/DSM_202503111011_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_13/DSM_202503111011_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_14/DSM_202503111011_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_15/DSM_202503111011_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_16/DSM_202503111011_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_17/DSM_202503111011_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_18/DSM_202503111011_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_19/DSM_202503111011_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_20/DSM_202503111011_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_21/DSM_202503111011_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_22/DSM_202503111011_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_23/DSM_202503111011_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_24/DSM_202503111011_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_25/DSM_202503111011_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_26/DSM_202503111011_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_27/DSM_202503111011_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_28/DSM_202503111011_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_29/DSM_202503111011_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_30/DSM_202503111011_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_31/DSM_202503111011_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_32/DSM_202503111011_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_33/DSM_202503111011_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_34/DSM_202503111011_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_35/DSM_202503111011_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_36/DSM_202503111011_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_37/DSM_202503111011_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_38/DSM_202503111011_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_39/DSM_202503111011_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_40/DSM_202503111011_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_41/DSM_202503111011_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_42/DSM_202503111011_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_43/DSM_202503111011_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_44/DSM_202503111011_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_45/DSM_202503111011_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_46/DSM_202503111011_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_47/DSM_202503111011_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_48/DSM_202503111011_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_49/DSM_202503111011_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_50/DSM_202503111011_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_51/DSM_202503111011_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_52/DSM_202503111011_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_53/DSM_202503111011_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_54/DSM_202503111011_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_55/DSM_202503111011_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_56/DSM_202503111011_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_57/DSM_202503111011_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_58/DSM_202503111011_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_59/DSM_202503111011_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503111011/DSM_202503111011_60/DSM_202503111011_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_1/DSM_202503210851_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_2/DSM_202503210851_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_3/DSM_202503210851_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_4/DSM_202503210851_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_5/DSM_202503210851_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_6/DSM_202503210851_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_7/DSM_202503210851_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_8/DSM_202503210851_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_9/DSM_202503210851_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_10/DSM_202503210851_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_11/DSM_202503210851_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_12/DSM_202503210851_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_13/DSM_202503210851_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_14/DSM_202503210851_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_15/DSM_202503210851_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_16/DSM_202503210851_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_17/DSM_202503210851_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_18/DSM_202503210851_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_19/DSM_202503210851_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_20/DSM_202503210851_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_21/DSM_202503210851_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_22/DSM_202503210851_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_23/DSM_202503210851_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_24/DSM_202503210851_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_25/DSM_202503210851_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_26/DSM_202503210851_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_27/DSM_202503210851_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_28/DSM_202503210851_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_29/DSM_202503210851_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_30/DSM_202503210851_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_31/DSM_202503210851_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_32/DSM_202503210851_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_33/DSM_202503210851_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_34/DSM_202503210851_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_35/DSM_202503210851_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_36/DSM_202503210851_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_37/DSM_202503210851_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_38/DSM_202503210851_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_39/DSM_202503210851_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_40/DSM_202503210851_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_41/DSM_202503210851_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_42/DSM_202503210851_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_43/DSM_202503210851_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_44/DSM_202503210851_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_45/DSM_202503210851_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_46/DSM_202503210851_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_47/DSM_202503210851_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_48/DSM_202503210851_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_49/DSM_202503210851_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_50/DSM_202503210851_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_51/DSM_202503210851_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_52/DSM_202503210851_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_53/DSM_202503210851_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_54/DSM_202503210851_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_55/DSM_202503210851_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_56/DSM_202503210851_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_57/DSM_202503210851_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_58/DSM_202503210851_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_59/DSM_202503210851_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503210851/DSM_202503210851_60/DSM_202503210851_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_1/DSM_202503260955_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_2/DSM_202503260955_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_3/DSM_202503260955_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_4/DSM_202503260955_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_5/DSM_202503260955_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_6/DSM_202503260955_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_7/DSM_202503260955_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_8/DSM_202503260955_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_9/DSM_202503260955_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_10/DSM_202503260955_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_11/DSM_202503260955_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_12/DSM_202503260955_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_13/DSM_202503260955_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_14/DSM_202503260955_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_15/DSM_202503260955_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_16/DSM_202503260955_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_17/DSM_202503260955_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_18/DSM_202503260955_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_19/DSM_202503260955_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_20/DSM_202503260955_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_21/DSM_202503260955_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_22/DSM_202503260955_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_23/DSM_202503260955_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_24/DSM_202503260955_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_25/DSM_202503260955_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_26/DSM_202503260955_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_27/DSM_202503260955_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_28/DSM_202503260955_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_29/DSM_202503260955_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_30/DSM_202503260955_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_31/DSM_202503260955_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_32/DSM_202503260955_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_33/DSM_202503260955_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_34/DSM_202503260955_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_35/DSM_202503260955_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_36/DSM_202503260955_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_37/DSM_202503260955_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_38/DSM_202503260955_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_39/DSM_202503260955_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_40/DSM_202503260955_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_41/DSM_202503260955_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_42/DSM_202503260955_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_43/DSM_202503260955_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_44/DSM_202503260955_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_45/DSM_202503260955_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_46/DSM_202503260955_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_47/DSM_202503260955_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_48/DSM_202503260955_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_49/DSM_202503260955_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_50/DSM_202503260955_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_51/DSM_202503260955_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_52/DSM_202503260955_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_53/DSM_202503260955_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_54/DSM_202503260955_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_55/DSM_202503260955_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_56/DSM_202503260955_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_57/DSM_202503260955_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_58/DSM_202503260955_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_59/DSM_202503260955_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202503260955/DSM_202503260955_60/DSM_202503260955_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_1/DSM_202504040926_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_2/DSM_202504040926_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_3/DSM_202504040926_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_4/DSM_202504040926_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_5/DSM_202504040926_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_6/DSM_202504040926_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_7/DSM_202504040926_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_8/DSM_202504040926_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_9/DSM_202504040926_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_10/DSM_202504040926_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_11/DSM_202504040926_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_12/DSM_202504040926_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_13/DSM_202504040926_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_14/DSM_202504040926_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_15/DSM_202504040926_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_16/DSM_202504040926_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_17/DSM_202504040926_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_18/DSM_202504040926_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_19/DSM_202504040926_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_20/DSM_202504040926_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_21/DSM_202504040926_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_22/DSM_202504040926_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_23/DSM_202504040926_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_24/DSM_202504040926_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_25/DSM_202504040926_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_26/DSM_202504040926_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_27/DSM_202504040926_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_28/DSM_202504040926_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_29/DSM_202504040926_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_30/DSM_202504040926_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_31/DSM_202504040926_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_32/DSM_202504040926_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_33/DSM_202504040926_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_34/DSM_202504040926_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_35/DSM_202504040926_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_36/DSM_202504040926_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_37/DSM_202504040926_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_38/DSM_202504040926_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_39/DSM_202504040926_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_40/DSM_202504040926_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_41/DSM_202504040926_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_42/DSM_202504040926_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_43/DSM_202504040926_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_44/DSM_202504040926_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_45/DSM_202504040926_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_46/DSM_202504040926_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_47/DSM_202504040926_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_48/DSM_202504040926_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_49/DSM_202504040926_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_50/DSM_202504040926_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_51/DSM_202504040926_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_52/DSM_202504040926_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_53/DSM_202504040926_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_54/DSM_202504040926_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_55/DSM_202504040926_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_56/DSM_202504040926_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_57/DSM_202504040926_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_58/DSM_202504040926_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_59/DSM_202504040926_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504040926/DSM_202504040926_60/DSM_202504040926_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_1/DSM_202504080849_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_2/DSM_202504080849_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_3/DSM_202504080849_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_4/DSM_202504080849_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_5/DSM_202504080849_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_6/DSM_202504080849_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_7/DSM_202504080849_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_8/DSM_202504080849_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_9/DSM_202504080849_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_10/DSM_202504080849_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_11/DSM_202504080849_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_12/DSM_202504080849_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_13/DSM_202504080849_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_14/DSM_202504080849_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_15/DSM_202504080849_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_16/DSM_202504080849_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_17/DSM_202504080849_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_18/DSM_202504080849_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_19/DSM_202504080849_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_20/DSM_202504080849_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_21/DSM_202504080849_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_22/DSM_202504080849_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_23/DSM_202504080849_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_24/DSM_202504080849_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_25/DSM_202504080849_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_26/DSM_202504080849_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_27/DSM_202504080849_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_28/DSM_202504080849_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_29/DSM_202504080849_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_30/DSM_202504080849_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_31/DSM_202504080849_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_32/DSM_202504080849_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_33/DSM_202504080849_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_34/DSM_202504080849_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_35/DSM_202504080849_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_36/DSM_202504080849_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_37/DSM_202504080849_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_38/DSM_202504080849_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_39/DSM_202504080849_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_40/DSM_202504080849_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_41/DSM_202504080849_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_42/DSM_202504080849_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_43/DSM_202504080849_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_44/DSM_202504080849_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_45/DSM_202504080849_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_46/DSM_202504080849_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_47/DSM_202504080849_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_48/DSM_202504080849_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_49/DSM_202504080849_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_50/DSM_202504080849_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_51/DSM_202504080849_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_52/DSM_202504080849_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_53/DSM_202504080849_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_54/DSM_202504080849_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_55/DSM_202504080849_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_56/DSM_202504080849_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_57/DSM_202504080849_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_58/DSM_202504080849_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_59/DSM_202504080849_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504080849/DSM_202504080849_60/DSM_202504080849_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_1/DSM_202504170935_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_2/DSM_202504170935_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_3/DSM_202504170935_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_4/DSM_202504170935_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_5/DSM_202504170935_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_6/DSM_202504170935_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_7/DSM_202504170935_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_8/DSM_202504170935_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_9/DSM_202504170935_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_10/DSM_202504170935_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_11/DSM_202504170935_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_12/DSM_202504170935_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_13/DSM_202504170935_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_14/DSM_202504170935_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_15/DSM_202504170935_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_16/DSM_202504170935_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_17/DSM_202504170935_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202504170935/DSM_202504170935_18/DSM_202504170935_18_original.tif',
# ...
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_55/DSM_202506021002_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_56/DSM_202506021002_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_57/DSM_202506021002_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_58/DSM_202506021002_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_59/DSM_202506021002_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506021002/DSM_202506021002_60/DSM_202506021002_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_1/DSM_202506130855_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_2/DSM_202506130855_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_3/DSM_202506130855_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_4/DSM_202506130855_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_5/DSM_202506130855_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_6/DSM_202506130855_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_7/DSM_202506130855_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_8/DSM_202506130855_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_9/DSM_202506130855_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_10/DSM_202506130855_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_11/DSM_202506130855_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_12/DSM_202506130855_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_13/DSM_202506130855_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_14/DSM_202506130855_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_15/DSM_202506130855_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_16/DSM_202506130855_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_17/DSM_202506130855_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_18/DSM_202506130855_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_19/DSM_202506130855_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_20/DSM_202506130855_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_21/DSM_202506130855_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_22/DSM_202506130855_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_23/DSM_202506130855_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_24/DSM_202506130855_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_25/DSM_202506130855_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_26/DSM_202506130855_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_27/DSM_202506130855_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_28/DSM_202506130855_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_29/DSM_202506130855_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_30/DSM_202506130855_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_31/DSM_202506130855_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_32/DSM_202506130855_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_33/DSM_202506130855_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_34/DSM_202506130855_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_35/DSM_202506130855_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_36/DSM_202506130855_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_37/DSM_202506130855_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_38/DSM_202506130855_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_39/DSM_202506130855_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_40/DSM_202506130855_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_41/DSM_202506130855_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_42/DSM_202506130855_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_43/DSM_202506130855_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_44/DSM_202506130855_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_45/DSM_202506130855_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_46/DSM_202506130855_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_47/DSM_202506130855_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_48/DSM_202506130855_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_49/DSM_202506130855_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_50/DSM_202506130855_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_51/DSM_202506130855_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_52/DSM_202506130855_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_53/DSM_202506130855_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_54/DSM_202506130855_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_55/DSM_202506130855_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_56/DSM_202506130855_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_57/DSM_202506130855_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_58/DSM_202506130855_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_59/DSM_202506130855_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202506130855/DSM_202506130855_60/DSM_202506130855_60_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_1/DSM_202505291010_1_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_2/DSM_202505291010_2_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_3/DSM_202505291010_3_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_4/DSM_202505291010_4_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_5/DSM_202505291010_5_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_6/DSM_202505291010_6_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_7/DSM_202505291010_7_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_8/DSM_202505291010_8_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_9/DSM_202505291010_9_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_10/DSM_202505291010_10_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_11/DSM_202505291010_11_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_12/DSM_202505291010_12_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_13/DSM_202505291010_13_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_14/DSM_202505291010_14_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_15/DSM_202505291010_15_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_16/DSM_202505291010_16_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_17/DSM_202505291010_17_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_18/DSM_202505291010_18_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_19/DSM_202505291010_19_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_20/DSM_202505291010_20_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_21/DSM_202505291010_21_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_22/DSM_202505291010_22_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_23/DSM_202505291010_23_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_24/DSM_202505291010_24_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_25/DSM_202505291010_25_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_26/DSM_202505291010_26_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_27/DSM_202505291010_27_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_28/DSM_202505291010_28_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_29/DSM_202505291010_29_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_30/DSM_202505291010_30_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_31/DSM_202505291010_31_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_32/DSM_202505291010_32_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_33/DSM_202505291010_33_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_34/DSM_202505291010_34_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_35/DSM_202505291010_35_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_36/DSM_202505291010_36_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_37/DSM_202505291010_37_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_38/DSM_202505291010_38_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_39/DSM_202505291010_39_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_40/DSM_202505291010_40_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_41/DSM_202505291010_41_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_42/DSM_202505291010_42_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_43/DSM_202505291010_43_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_44/DSM_202505291010_44_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_45/DSM_202505291010_45_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_46/DSM_202505291010_46_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_47/DSM_202505291010_47_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_48/DSM_202505291010_48_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_49/DSM_202505291010_49_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_50/DSM_202505291010_50_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_51/DSM_202505291010_51_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_52/DSM_202505291010_52_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_53/DSM_202505291010_53_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_54/DSM_202505291010_54_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_55/DSM_202505291010_55_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_56/DSM_202505291010_56_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_57/DSM_202505291010_57_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_58/DSM_202505291010_58_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_59/DSM_202505291010_59_original.tif',
#  '/Volumes/PortableSSD/dataForProcess/2025MainData/DSM/DSM_202505291010/DSM_202505291010_60/DSM_202505291010_60_original.tif']
