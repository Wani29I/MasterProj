# %%
from MetaWeightingModel import MetaWeightingModel
from modelFunc import setAndTrainMetaModel, setAndTestMetaModel

# %%
setAndTrainMetaModel("meta_input_data.csv", "days", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "Height", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "LAI", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "SPAD", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "totalSeedNum", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "totalSeedWeightAfterDry", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "totEarNum", MetaWeightingModel)
setAndTrainMetaModel("meta_input_data.csv", "totEarWeight", MetaWeightingModel)
# Out:
# Model name: days_MetaWeightingModel
# Saving to: ./days_MetaWeightingModel
# Using device: cpu
# Inferred number of traits: 8 → Input shape: (26780, 16)
# Epoch 1/1000: 100%|██████████| 670/670 [00:01<00:00, 353.96it/s]
# Epoch 1 | Train Loss: 6618.9681 | Val Loss: 1070.7281
# Epoch 2/1000: 100%|██████████| 670/670 [00:01<00:00, 370.17it/s]
# Epoch 2 | Train Loss: 696.1485 | Val Loss: 356.3807
# Epoch 3/1000: 100%|██████████| 670/670 [00:01<00:00, 367.66it/s]
# Epoch 3 | Train Loss: 255.5099 | Val Loss: 126.4740
# Epoch 4/1000: 100%|██████████| 670/670 [00:01<00:00, 377.06it/s]
# Epoch 4 | Train Loss: 93.3677 | Val Loss: 36.7019
# Epoch 5/1000: 100%|██████████| 670/670 [00:01<00:00, 345.00it/s]
# Epoch 5 | Train Loss: 31.2958 | Val Loss: 8.1882
# Epoch 6/1000: 100%|██████████| 670/670 [00:01<00:00, 358.28it/s]
# Epoch 6 | Train Loss: 12.8929 | Val Loss: 3.6593
# Epoch 7/1000: 100%|██████████| 670/670 [00:01<00:00, 366.61it/s]
# Epoch 7 | Train Loss: 9.7134 | Val Loss: 3.7779
# ...

# %%
setAndTestMetaModel("meta_input_data.csv", "days", MetaWeightingModel, "days_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "Height", MetaWeightingModel, "Height_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "LAI", MetaWeightingModel, "LAI_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "SPAD", MetaWeightingModel, "SPAD_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "totalSeedNum", MetaWeightingModel, "totalSeedNum_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "totalSeedWeightAfterDry", MetaWeightingModel, "totalSeedWeightAfterDry_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "totEarNum", MetaWeightingModel, "totEarNum_MetaWeightingModel.pth")
setAndTestMetaModel("meta_input_data.csv", "totEarWeight", MetaWeightingModel, "totEarWeight_MetaWeightingModel.pth")
# Out:
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1523.35it/s]
# Meta Model Test Results:
# R² Score : -0.0471
# MAE      : 14.5755
# RMSE     : 16.9093
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1386.94it/s]
# Meta Model Test Results:
# R² Score : 0.0480
# MAE      : 7.5015
# RMSE     : 11.9044
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1527.19it/s]
# Meta Model Test Results:
# R² Score : 0.6686
# MAE      : 0.4358
# RMSE     : 0.6079
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1501.84it/s]
# Meta Model Test Results:
# R² Score : 0.7832
# MAE      : 3.9290
# RMSE     : 5.4464
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1417.78it/s]
# Meta Model Test Results:
# R² Score : 0.7315
# MAE      : 553.2641
# RMSE     : 774.4248
# Using device: cpu
# Testing: 100%|██████████| 168/168 [00:00<00:00, 1184.24it/s]
# Meta Model Test Results:
# R² Score : 0.9017
# ...
